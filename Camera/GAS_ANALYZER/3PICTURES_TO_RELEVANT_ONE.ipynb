# %%
import cv2
import numpy as np
from pathlib import Path
import random
import os

# %%
# Configuration for Random Cropping (Cell 2)

# Input/Output directories
RANDOM_CROP_INPUT = r"C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures"
RANDOM_CROP_OUTPUT = r"C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures"

# Crop sizes (in pixels)
CROP_SIZES = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200]

# Number of crops to generate per size
CROPS_PER_SIZE = 10

# %%
def extract_random_crops(input_dir, output_dir, crop_sizes, crops_per_size):
    """Extract random crops from each image with varying sizes"""
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    if not input_path.exists():
        print(f"Error: Input directory not found: {input_dir}")
        return
    
    output_path.mkdir(parents=True, exist_ok=True)
    
    image_extensions = ['.jpg', '.jpeg', '.png', '.bmp']
    images = []
    for ext in image_extensions:
        images.extend(input_path.rglob(f'*{ext}'))
    
    if not images:
        print("No images found")
        return
    
    print(f"Found {len(images)} images to process")
    print(f"Will generate {len(crop_sizes)} sizes × {crops_per_size} crops = {len(crop_sizes) * crops_per_size} crops per image")
    print(f"Total crops: {len(images) * len(crop_sizes) * crops_per_size}")
    print("="*60)
    
    processed_images = 0
    total_crops = 0
    
    for img_idx, img_path in enumerate(images, 1):
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"✗ Could not read: {img_path.name}")
            continue
        
        height, width = img.shape[:2]
        
        img_folder = output_path / img_path.stem
        img_folder.mkdir(exist_ok=True)
        
        print(f"[{img_idx}/{len(images)}] Processing: {img_path.name} ({width}×{height})")
        
        for crop_size in crop_sizes:
            if crop_size > width or crop_size > height:
                print(f"  ⚠️ Skipping {crop_size}×{crop_size} (image too small)")
                continue
            
            size_folder = img_folder / f"{crop_size}x{crop_size}"
            size_folder.mkdir(exist_ok=True)
            
            used_positions = []
            crops_generated = 0
            attempts = 0
            max_attempts = crops_per_size * 100
            
            while crops_generated < crops_per_size and attempts < max_attempts:
                attempts += 1
                
                x = random.randint(0, width - crop_size)
                y = random.randint(0, height - crop_size)
                
                overlap = False
                for prev_x, prev_y, prev_size in used_positions:
                    overlap_area = max(0, min(x + crop_size, prev_x + prev_size) - max(x, prev_x)) * \
                                   max(0, min(y + crop_size, prev_y + prev_size) - max(y, prev_y))
                    crop_area = crop_size * crop_size
                    overlap_ratio = overlap_area / crop_area
                    
                    if overlap_ratio >= 0.9:
                        overlap = True
                        break
                
                if not overlap:
                    crop = img[y:y+crop_size, x:x+crop_size]
                    crop_filename = size_folder / f"crop_{crops_generated+1:03d}.jpg"
                    cv2.imwrite(str(crop_filename), crop, [cv2.IMWRITE_JPEG_QUALITY, 95])
                    
                    used_positions.append((x, y, crop_size))
                    crops_generated += 1
                    total_crops += 1
            
            if crops_generated < crops_per_size:
                print(f"  ⚠️ Only generated {crops_generated}/{crops_per_size} crops for {crop_size}×{crop_size}")
        
        processed_images += 1
        print(f"  ✓ Generated crops in: {img_folder}")
    
    print("="*60)
    print(f"SUMMARY")
    print("="*60)
jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00007
# [17513/17523] Processing: frame_00008.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00008
# [17514/17523] Processing: frame_00009.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00009
# [17515/17523] Processing: frame_00010.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00010
# [17516/17523] Processing: frame_00011.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00011
# [17517/17523] Processing: frame_00012.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00012
# [17518/17523] Processing: frame_00013.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00013
# [17519/17523] Processing: frame_00014.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00014
# [17520/17523] Processing: frame_00015.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00015
# [17521/17523] Processing: frame_00016.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00016
# [17522/17523] Processing: frame_00017.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00017
# [17523/17523] Processing: frame_00018.jpg (1440×1080)
#   ✓ Generated crops in: C:\Users\thaim\Videos\AI_LEDS\cropped_no_detector_pictures\frame_00018
# ============================================================
# SUMMARY
# ============================================================
# Images processed: 17523/17523
# Total crops generated: 1752300
# ============================================================

# %%
class ROISelector:
    def __init__(self):
        self.roi = None
        self.drawing = False
        self.start_point = None
        self.image = None
        self.clone = None
    
    def select_roi(self, image_path):
        """Let user select ROI from an image"""
        img = cv2.imread(str(image_path))
        if img is None:
            print(f"Error: Cannot read image {image_path}")
            return None
        
        self.image = img.copy()
        self.clone = img.copy()
        
        cv2.namedWindow("Select ROI - Press ENTER when done, 'r' to reset")
        cv2.setMouseCallback("Select ROI - Press ENTER when done, 'r' to reset", self.mouse_callback)
        
        print("\nDraw a rectangle for the ROI:")
        print("- Click and drag to draw rectangle")
        print("- Press 'r' to reset")
        print("- Press ENTER when done")
        print("- Press ESC to skip this folder\n")
        
        while True:
            cv2.imshow("Select ROI - Press ENTER when done, 'r' to reset", self.image)
            key = cv2.waitKey(1) & 0xFF
            
            if key == 13:
                if self.roi is not None:
                    break
            elif key == ord('r'):
                self.image = self.clone.copy()
                self.roi = None
            elif key == 27:
                cv2.destroyAllWindows()
                return None
        
        cv2.destroyAllWindows()
        return self.roi
    
    def mouse_callback(self, event, x, y, flags, param):
        """Handle mouse events for ROI selection"""
        if event == cv2.EVENT_LBUTTONDOWN:
            self.drawing = True
            self.start_point = (x, y)
        
        elif event == cv2.EVENT_MOUSEMOVE:
            if self.drawing:
                self.image = self.clone.copy()
                cv2.rectangle(self.image, self.start_point, (x, y), (0, 255, 0), 2)
        
        elif event == cv2.EVENT_LBUTTONUP:
            self.drawing = False
            cv2.rectangle(self.image, self.start_point, (x, y), (0, 255, 0), 2)
            x1, y1 = self.start_point
            x2, y2 = x, y
            self.roi = (min(x1, x2), min(y1, y2), abs(x2 - x1), abs(y2 - y1))

def crop_images_with_roi(input_dir, output_dir):
    """Crop all images in subfolders using one ROI per subfolder"""
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    if not input_path.exists():
        print(f"Error: Input directory not found: {input_dir}")
        return
    
    output_path.mkdir(parents=True, exist_ok=True)
    
    subfolders = [f for f in input_path.iterdir() if f.is_dir()]
    
    if not subfolders:
        print("No subfolders found")
        return
    
    print(f"Found {len(subfolders)} subfolders to process")
    print("="*60)
    
    processed_folders = 0
    skipped_folders = 0
    total_images = 0
    
    for folder_idx, subfolder in enumerate(subfolders, 1):
        image_extensions = ['.jpg', '.jpeg', '.png', '.bmp']
        images = []
        for ext in image_extensions:
            images.extend(subfolder.glob(f'*{ext}'))
        
        if not images:
            print(f"[{folder_idx}/{len(subfolders)}] Skipping {subfolder.name} (no images)")
            skipped_folders += 1
            continue
        
        print(f"\n[{folder_idx}/{len(subfolders)}] Folder: {subfolder.name} ({len(images)} images)")
        
        first_image = images[0]
        roi_selector = ROISelector()
        roi = roi_selector.select_roi(first_image)
        
        if roi is None:
            print(f"  Skipped by user")
            skipped_folders += 1
            continue
        
        x, y, w, h = roi
        print(f"  ROI selected: x={x}, y={y}, w={w}, h={h}")
        
        output_subfolder_name = f"{subfolder.name}_{w}x{h}"
        output_subfolder = output_path / output_subfolder_name
        output_subfolder.mkdir(exist_ok=True)
        
        for img_path in images:
            img = cv2.imread(str(img_path))
            if img is None:
                print(f"  ✗ Could not read: {img_path.name}")
                continue
            
            cropped = img[y:y+h, x:x+w]
            
            img_stem = img_path.stem
            img_ext = img_path.suffix
            output_img_name = f"{img_stem}_{w}x{h}{img_ext}"
            output_img_path = output_subfolder / output_img_name
            
            cv2.imwrite(str(output_img_path), cropped, [cv2.IMWRITE_JPEG_QUALITY, 95])
            total_images += 1
        
        print(f"  ✓ Cropped {len(images)} images → {output_subfolder}")
        processed_folders += 1
    
    print("\n" + "="*60)
    print(f"SUMMARY")
    print("="*60)
    print(f"Folders processed: {processed_folders}/{len(subfolders)}")
    print(f"Folders skipped: {skipped_folders}")
    print(f"Total images cropped: {total_images}")
    print("="*60)

# Configuration
INPUT_DIR = r"C:\Users\thaim\Videos\AI_LEDS\detector_pictures"
OUTPUT_DIR = r"C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures"

# Run ROI cropping
crop_images_with_roi(INPUT_DIR, OUTPUT_DIR)
# Out:
# Found 43 subfolders to process
# ============================================================
#
# [1/43] Folder: 001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1 (708 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=457, y=585, w=39, h=65
#   ✓ Cropped 708 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1_39x65
#
# [2/43] Folder: 002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1 (908 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=451, y=588, w=33, h=58
#   ✓ Cropped 908 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1_33x58
#
# [3/43] Folder: 005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf (1917 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=181, y=419, w=47, h=79
#   ✓ Cropped 1917 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf_47x79
#
# [4/43] Folder: 006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf (296 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=171, y=416, w=57, h=91
#   ✓ Cropped 296 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf_57x91
#
# [5/43] Folder: 007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn (1146 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=167, y=410, w=61, h=79
#   ✓ Cropped 1146 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn_61x79
#
# [6/43] Folder: 008_40_lmalh_zvvyt_ymynh (1211 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=380, y=511, w=40, h=66
#   ✓ Cropped 1211 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\008_40_lmalh_zvvyt_ymynh_40x66
#
# [7/43] Folder: 009_40_rtz (487 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=385, y=515, w=40, h=53
#   ✓ Cropped 487 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\009_40_rtz_40x53
#
# [8/43] Folder: 010_40_ymynh_lmth (169 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=393, y=519, w=45, h=63
#   ✓ Cropped 169 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\010_40_ymynh_lmth_45x63
#
# [9/43] Folder: 011_50_zvvyt_ymynh (563 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=724, y=616, w=33, h=56
#   ✓ Cropped 563 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\011_50_zvvyt_ymynh_33x56
#
# [10/43] Folder: 012_rtz_50 (390 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=739, y=616, w=30, h=53
#   ✓ Cropped 390 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\012_rtz_50_30x53
#
# [11/43] Folder: 013_zvvyt_lmalh_50 (376 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=722, y=635, w=27, h=48
#   ✓ Cropped 376 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\013_zvvyt_lmalh_50_27x48
#
# [12/43] Folder: 014_zvvyt_lmth_50 (310 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=725, y=639, w=37, h=59
#   ✓ Cropped 310 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\014_zvvyt_lmth_50_37x59
#
# [13/43] Folder: 015_zvvyt_shmalh_50 (374 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=721, y=616, w=39, h=56
#   ✓ Cropped 374 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\015_zvvyt_shmalh_50_39x56
#
# [14/43] Folder: 017_1205 (4)-1 (88 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=500, y=577, w=42, h=79
#   ✓ Cropped 88 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\017_1205 (4)-1_42x79
#
# [15/43] Folder: 018_1205 (4)(1)-1 (100 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=791, y=582, w=48, h=77
#   ✓ Cropped 100 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\018_1205 (4)(1)-1_48x77
#
# [16/43] Folder: 020_1205 (4)(11)-1 (51 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=755, y=633, w=43, h=69
#   ✓ Cropped 51 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\020_1205 (4)(11)-1_43x69
#
# [17/43] Folder: 021_1205 (4)(12)-1 (127 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=835, y=974, w=37, h=72
#   ✓ Cropped 127 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\021_1205 (4)(12)-1_37x72
#
# [18/43] Folder: 022_1205 (4)(13)-1 (131 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=755, y=998, w=41, h=66
#   ✓ Cropped 131 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\022_1205 (4)(13)-1_41x66
#
# [19/43] Folder: 023_1205 (4)(2)-1 (70 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=1103, y=592, w=38, h=75
#   ✓ Cropped 70 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\023_1205 (4)(2)-1_38x75
#
# [20/43] Folder: 024_1205 (4)(3)-1 (288 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=1238, y=589, w=40, h=72
#   ✓ Cropped 288 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\024_1205 (4)(3)-1_40x72
#
# [21/43] Folder: 025_1205 (4)(4)-1 (133 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=374, y=585, w=38, h=74
#   ✓ Cropped 133 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\025_1205 (4)(4)-1_38x74
#
# [22/43] Folder: 026_1205 (4)(5)-1 (49 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=857, y=593, w=38, h=74
#   ✓ Cropped 49 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\026_1205 (4)(5)-1_38x74
#
# [23/43] Folder: 027_1205 (4)(6)-1 (33 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=371, y=585, w=47, h=66
#   ✓ Cropped 33 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\027_1205 (4)(6)-1_47x66
#
# [24/43] Folder: 028_1205 (4)(7)-1 (36 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=733, y=601, w=35, h=64
#   ✓ Cropped 36 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\028_1205 (4)(7)-1_35x64
#
# [25/43] Folder: 029_1205 (4)(8)-1 (40 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=715, y=316, w=42, h=74
#   ✓ Cropped 40 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\029_1205 (4)(8)-1_42x74
#
# [26/43] Folder: 045_1205 (4)-1 (2592 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=499, y=586, w=42, h=67
#   ✓ Cropped 2592 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\045_1205 (4)-1_42x67
#
# [27/43] Folder: 049_1205-1 (40 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=1002, y=633, w=28, h=46
#   ✓ Cropped 40 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\049_1205-1_28x46
#
# [28/43] Folder: 050_1205(1)-1 (33 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=359, y=622, w=29, h=40
#   ✓ Cropped 33 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\050_1205(1)-1_29x40
#
# [29/43] Folder: 051_1205(2)-1 (55 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=656, y=629, w=31, h=51
#   ✓ Cropped 55 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\051_1205(2)-1_31x51
#
# [30/43] Folder: 052_1205(3)-1 (18 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=661, y=626, w=24, h=51
#   ✓ Cropped 18 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\052_1205(3)-1_24x51
#
# [31/43] Folder: 053_1205(4)-1 (10 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=663, y=206, w=30, h=46
#   ✓ Cropped 10 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\053_1205(4)-1_30x46
#
# [32/43] Folder: 054_1205(5)-1 (18 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=660, y=385, w=26, h=47
#   ✓ Cropped 18 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\054_1205(5)-1_26x47
#
# [33/43] Folder: 055_1205(6)-1 (16 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=661, y=630, w=24, h=50
#   ✓ Cropped 16 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\055_1205(6)-1_24x50
#
# [34/43] Folder: 056_1205(7)-1 (27 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=661, y=756, w=21, h=45
#   ✓ Cropped 27 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\056_1205(7)-1_21x45
#
# [35/43] Folder: 057_1205(8)-1 (376 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=707, y=821, w=21, h=42
#   ✓ Cropped 376 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\057_1205(8)-1_21x42
#
# [36/43] Folder: 067_1205-1 (4613 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=633, y=629, w=31, h=52
#   ✓ Cropped 4613 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\067_1205-1_31x52
#
# [37/43] Folder: 070_1205 (1)-1 (221 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=784, y=335, w=113, h=207
#   ✓ Cropped 221 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\070_1205 (1)-1_113x207
#
# [38/43] Folder: 071_1205 (1)(1)-1 (15 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=604, y=227, w=99, h=191
#   ✓ Cropped 15 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\071_1205 (1)(1)-1_99x191
#
# [39/43] Folder: 081_1205 (1)(2)-1 (18 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=585, y=292, w=87, h=188
#   ✓ Cropped 18 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\081_1205 (1)(2)-1_87x188
#
# [40/43] Folder: 082_1205 (1)(3)-1 (16 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=559, y=370, w=119, h=172
#   ✓ Cropped 16 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\082_1205 (1)(3)-1_119x172
#
# [41/43] Folder: 083_1205 (1)(4)-1 (27 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=590, y=452, w=98, h=193
#   ✓ Cropped 27 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\083_1205 (1)(4)-1_98x193
#
# [42/43] Folder: 084_1205 (1)(5)-1 (42 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=544, y=526, w=113, h=192
#   ✓ Cropped 42 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\084_1205 (1)(5)-1_113x192
#
# [43/43] Folder: 085_1205 (1)(6)-1 (19 images)
#
# Draw a rectangle for the ROI:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this folder
#
#   ROI selected: x=541, y=599, w=105, h=203
#   ✓ Cropped 19 images → C:\Users\thaim\Videos\AI_LEDS\cropped_detector_pictures\085_1205 (1)(6)-1_105x203
#
# ============================================================
# SUMMARY
# ============================================================
# Folders processed: 43/43
# Folders skipped: 0
# Total images cropped: 18157
# ============================================================
