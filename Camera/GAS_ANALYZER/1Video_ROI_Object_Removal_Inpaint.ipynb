# %%
import os
import cv2
import numpy as np
from pathlib import Path
import subprocess
import shutil
import sys

# %%
# ROI Selection class
class ROISelector:
    def __init__(self):
        self.roi = None
        self.drawing = False
        self.start_point = None
        self.image = None
        self.clone = None
    
    def select_roi(self, video_path):
        """Let user select ROI from first frame of video"""
        cap = cv2.VideoCapture(str(video_path))
        ret, frame = cap.read()
        cap.release()
        
        if not ret:
            print(f"Error: Cannot read video {video_path}")
            return None
        
        self.image = frame.copy()
        self.clone = frame.copy()
        
        cv2.namedWindow("Select ROI - Press ENTER when done, 'r' to reset")
        cv2.setMouseCallback("Select ROI - Press ENTER when done, 'r' to reset", self.mouse_callback)
        
        print("\nDraw a rectangle around the object to remove:")
        print("- Click and drag to draw rectangle")
        print("- Press 'r' to reset")
        print("- Press ENTER when done")
        print("- Press ESC to skip this video\n")
        
        while True:
            cv2.imshow("Select ROI - Press ENTER when done, 'r' to reset", self.image)
            key = cv2.waitKey(1) & 0xFF
            
            if key == 13:  # Enter
                if self.roi is not None:
                    break
            elif key == ord('r'):  # Reset
                self.image = self.clone.copy()
                self.roi = None
            elif key == 27:  # ESC
                cv2.destroyAllWindows()
                return None
        
        cv2.destroyAllWindows()
        return self.roi
    
    def mouse_callback(self, event, x, y, flags, param):
        """Handle mouse events for ROI selection"""
        if event == cv2.EVENT_LBUTTONDOWN:
            self.drawing = True
            self.start_point = (x, y)
        
        elif event == cv2.EVENT_MOUSEMOVE:
            if self.drawing:
                self.image = self.clone.copy()
                cv2.rectangle(self.image, self.start_point, (x, y), (0, 255, 0), 2)
        
        elif event == cv2.EVENT_LBUTTONUP:
            self.drawing = False
            cv2.rectangle(self.image, self.start_point, (x, y), (0, 255, 0), 2)
            x1, y1 = self.start_point
            x2, y2 = x, y
            self.roi = (min(x1, x2), min(y1, y2), abs(x2 - x1), abs(y2 - y1))

# %%
def create_mask_video(video_path, roi, output_mask_dir):
    """Create mask frames from ROI"""
    cap = cv2.VideoCapture(str(video_path))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    mask_dir = output_mask_dir / f"{video_path.stem}_mask"
    mask_dir.mkdir(exist_ok=True)
    
    x, y, w, h = roi
    
    print(f"Creating mask frames: {frame_count} frames...")
    frame_idx = 0
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        mask = np.zeros((height, width), dtype=np.uint8)
        mask[y:y+h, x:x+w] = 255
        
        mask_filename = mask_dir / f"{frame_idx:05d}.png"
        cv2.imwrite(str(mask_filename), mask)
        frame_idx += 1
        
        if frame_idx % 100 == 0:
            print(f"  Processed {frame_idx}/{frame_count} frames")
    
    cap.release()
    
    print(f"Mask frames saved: {mask_dir}")
    return mask_dir

def run_opencv_inpaint(video_path, roi, output_video_path):
    """Fallback: Simple OpenCV inpainting (faster, lower quality)"""
    print(f"\nUsing OpenCV inpainting (fast method)...")
    
    cap = cv2.VideoCapture(str(video_path))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(str(output_video_path), fourcc, fps, (width, height))
    
    x, y, w, h = roi
    mask = np.zeros((height, width), dtype=np.uint8)
    mask[y:y+h, x:x+w] = 255
    
    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        inpainted = cv2.inpaint(frame, mask, 3, cv2.INPAINT_TELEA)
        out.write(inpainted)
        
        frame_idx += 1
        if frame_idx % 100 == 0:
            print(f"  Processed {frame_idx}/{frame_count} frames")
    
    cap.release()
    out.release()
    
    print(f"✓ OpenCV inpainting completed")
    return True

def run_propainter(video_path, mask_path, output_video_path, propainter_dir):
    """Run ProPainter inference (disabled - use OpenCV fallback)"""
    print(f"\n⚠️ ProPainter has memory/performance issues with this video.")
    print(f"Skipping ProPainter...")
    return False

def process_video_with_propainter(video_path, output_dir, temp_dir, propainter_dir, use_opencv=True):
    """Process single video: ROI selection -> mask creation -> inpainting"""
    print(f"\n{'='*60}")
    print(f"Processing: {video_path.name}")
    print(f"{'='*60}")
    
    roi_selector = ROISelector()
    roi = roi_selector.select_roi(video_path)
    
    if roi is None:
        print("Skipped by user")
        return False
    
    print(f"ROI selected: x={roi[0]}, y={roi[1]}, w={roi[2]}, h={roi[3]}")
    
    output_video_path = output_dir / video_path.name
    
    if use_opencv:
        success = run_opencv_inpaint(video_path, roi, output_video_path)
    else:
        mask_path = create_mask_video(video_path, roi, temp_dir)
        success = run_propainter(video_path, mask_path, output_video_path, propainter_dir)
        try:
            shutil.rmtree(mask_path, ignore_errors=True)
        except:
            pass
    
    return success

# %%
def process_directory_tree(input_dir, output_dir, propainter_dir, use_opencv=True):
    """Process all videos in directory tree"""
    input_dir = Path(input_dir)
    output_dir = Path(output_dir)
    propainter_dir = Path(propainter_dir)
    
    if not input_dir.exists():
        print(f"Error: Input directory does not exist: {input_dir}")
        return
    
    output_dir.mkdir(parents=True, exist_ok=True)
    
    temp_dir = output_dir / "_temp_masks"
    temp_dir.mkdir(exist_ok=True)
    
    video_extensions = ['.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv']
    video_files = []
    
    for ext in video_extensions:
        video_files.extend(input_dir.rglob(f'*{ext}'))
    
    if not video_files:
        print(f"No video files found in {input_dir}")
        return
    
    method = "OpenCV (fast)" if use_opencv else "ProPainter (slow, high quality)"
    print(f"\nFound {len(video_files)} video files to process")
    print(f"Input directory: {input_dir}")
    print(f"Output directory: {output_dir}")
    print(f"Method: {method}\n")
    
    processed = 0
    skipped = 0
    failed = 0
    
    for idx, video_path in enumerate(video_files, 1):
        print(f"\n[{idx}/{len(video_files)}] Processing video...")
        
        rel_path = video_path.relative_to(input_dir)
        output_video_dir = output_dir / rel_path.parent
        output_video_dir.mkdir(parents=True, exist_ok=True)
        
        output_video_path = output_video_dir / video_path.name
        if output_video_path.exists():
            print(f"Already exists: {output_video_path}")
            user_choice = input("Overwrite? (y/n): ").lower()
            if user_choice != 'y':
                skipped += 1
                continue
        
        success = process_video_with_propainter(video_path, output_video_dir, temp_dir, propainter_dir, use_opencv)
        
        if success:
            processed += 1
        else:
            failed += 1
    
    try:
        shutil.rmtree(temp_dir)
    except:
        pass
    
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"Total videos: {len(video_files)}")
    print(f"Processed: {processed}")
    print(f"Skipped: {skipped}")
    print(f"Failed: {failed}")
    print(f"{'='*60}")

# %%
# Configuration
INPUT_DIR = r"C:\Users\thaim\Videos\AI_LEDS\second_dataset\detector_video"
OUTPUT_DIR = r"C:\Users\thaim\Videos\AI_LEDS\second_dataset\No_detector_video"
PROPAINTER_DIR = r"./ProPainter"

# Use OpenCV (fast, simpler) instead of ProPainter (slow, better quality)
USE_OPENCV = True

# Run processing
process_directory_tree(INPUT_DIR, OUTPUT_DIR, PROPAINTER_DIR, use_opencv=USE_OPENCV)
# Out:
# Found 55 video files to process
# Input directory: C:\Users\thaim\Videos\AI_LEDS\DETECTOR
# Output directory: C:\Users\thaim\Videos\AI_LEDS\NO_detector
# Method: OpenCV (fast)
#
#
# [1/55] Processing video...
#
# ============================================================
# Processing: 005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=182, y=421, w=76, h=90
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/1917 frames
#   Processed 200/1917 frames
#   Processed 300/1917 frames
#   Processed 400/1917 frames
#   Processed 500/1917 frames
#   Processed 600/1917 frames
#   Processed 700/1917 frames
#   Processed 800/1917 frames
#   Processed 900/1917 frames
#   Processed 1000/1917 frames
#   Processed 1100/1917 frames
#   Processed 1200/1917 frames
#   Processed 1300/1917 frames
#   Processed 1400/1917 frames
#   Processed 1500/1917 frames
#   Processed 1600/1917 frames
#   Processed 1700/1917 frames
#   Processed 1800/1917 frames
#   Processed 1900/1917 frames
# ✓ OpenCV inpainting completed
#
# [2/55] Processing video...
#
# ============================================================
# Processing: 006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=168, y=417, w=104, h=96
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/296 frames
#   Processed 200/296 frames
# ✓ OpenCV inpainting completed
#
# [3/55] Processing video...
#
# ============================================================
# Processing: 007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=164, y=408, w=91, h=86
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/1146 frames
#   Processed 200/1146 frames
#   Processed 300/1146 frames
#   Processed 400/1146 frames
#   Processed 500/1146 frames
#   Processed 600/1146 frames
#   Processed 700/1146 frames
#   Processed 800/1146 frames
#   Processed 900/1146 frames
#   Processed 1000/1146 frames
#   Processed 1100/1146 frames
# ✓ OpenCV inpainting completed
#
# [4/55] Processing video...
#
# ============================================================
# Processing: 008_40_lmalh_zvvyt_ymynh.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=384, y=520, w=60, h=56
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/1211 frames
#   Processed 200/1211 frames
#   Processed 300/1211 frames
#   Processed 400/1211 frames
#   Processed 500/1211 frames
#   Processed 600/1211 frames
#   Processed 700/1211 frames
#   Processed 800/1211 frames
#   Processed 900/1211 frames
#   Processed 1000/1211 frames
#   Processed 1100/1211 frames
#   Processed 1200/1211 frames
# ✓ OpenCV inpainting completed
#
# [5/55] Processing video...
#
# ============================================================
# Processing: 009_40_rtz.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=379, y=512, w=66, h=67
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/487 frames
#   Processed 200/487 frames
#   Processed 300/487 frames
#   Processed 400/487 frames
# ✓ OpenCV inpainting completed
#
# [6/55] Processing video...
#
# ============================================================
# Processing: 010_40_ymynh_lmth.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=369, y=490, w=130, h=141
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/169 frames
# ✓ OpenCV inpainting completed
#
# [7/55] Processing video...
#
# ============================================================
# Processing: 011_50_zvvyt_ymynh.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=723, y=620, w=49, h=54
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/563 frames
#   Processed 200/563 frames
#   Processed 300/563 frames
#   Processed 400/563 frames
#   Processed 500/563 frames
# ✓ OpenCV inpainting completed
#
# [8/55] Processing video...
#
# ============================================================
# Processing: 012_rtz_50.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=739, y=620, w=58, h=59
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/390 frames
#   Processed 200/390 frames
#   Processed 300/390 frames
# ✓ OpenCV inpainting completed
#
# [9/55] Processing video...
#
# ============================================================
# Processing: 013_zvvyt_lmalh_50.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=721, y=636, w=55, h=50
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/376 frames
#   Processed 200/376 frames
#   Processed 300/376 frames
# ✓ OpenCV inpainting completed
#
# [10/55] Processing video...
#
# ============================================================
# Processing: 014_zvvyt_lmth_50.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=727, y=644, w=56, h=52
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/310 frames
#   Processed 200/310 frames
#   Processed 300/310 frames
# ✓ OpenCV inpainting completed
#
# [11/55] Processing video...
#
# ============================================================
# Processing: 015_zvvyt_shmalh_50.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=724, y=627, w=57, h=48
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/374 frames
#   Processed 200/374 frames
#   Processed 300/374 frames
# ✓ OpenCV inpainting completed
#
# [12/55] Processing video...
#
# ============================================================
# Processing: 001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=451, y=589, w=71, h=65
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/708 frames
#   Processed 200/708 frames
#   Processed 300/708 frames
#   Processed 400/708 frames
#   Processed 500/708 frames
#   Processed 600/708 frames
#   Processed 700/708 frames
# ✓ OpenCV inpainting completed
#
# [13/55] Processing video...
#
# ============================================================
# Processing: 002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=446, y=586, w=70, h=64
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/908 frames
#   Processed 200/908 frames
#   Processed 300/908 frames
#   Processed 400/908 frames
#   Processed 500/908 frames
#   Processed 600/908 frames
#   Processed 700/908 frames
#   Processed 800/908 frames
#   Processed 900/908 frames
# ✓ OpenCV inpainting completed
#
# [14/55] Processing video...
#
# ============================================================
# Processing: 017_1205 (4)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=498, y=583, w=75, h=68
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [15/55] Processing video...
#
# ============================================================
# Processing: 018_1205 (4)(1)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=793, y=593, w=81, h=73
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/100 frames
# ✓ OpenCV inpainting completed
#
# [16/55] Processing video...
#
# ============================================================
# Processing: 020_1205 (4)(11)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=752, y=630, w=79, h=76
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [17/55] Processing video...
#
# ============================================================
# Processing: 021_1205 (4)(12)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=1275, y=71, w=9, h=12
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/127 frames
# ✓ OpenCV inpainting completed
#
# [18/55] Processing video...
#
# ============================================================
# Processing: 022_1205 (4)(13)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=623, y=658, w=20, h=24
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/131 frames
# ✓ OpenCV inpainting completed
#
# [19/55] Processing video...
#
# ============================================================
# Processing: 023_1205 (4)(2)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=1101, y=595, w=72, h=69
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [20/55] Processing video...
#
# ============================================================
# Processing: 024_1205 (4)(3)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=1235, y=591, w=76, h=68
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/288 frames
#   Processed 200/288 frames
# ✓ OpenCV inpainting completed
#
# [21/55] Processing video...
#
# ============================================================
# Processing: 025_1205 (4)(4)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=375, y=588, w=77, h=69
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/133 frames
# ✓ OpenCV inpainting completed
#
# [22/55] Processing video...
#
# ============================================================
# Processing: 026_1205 (4)(5)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=856, y=600, w=72, h=64
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [23/55] Processing video...
#
# ============================================================
# Processing: 027_1205 (4)(6)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=374, y=589, w=72, h=61
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [24/55] Processing video...
#
# ============================================================
# Processing: 028_1205 (4)(7)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=732, y=597, w=78, h=71
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [25/55] Processing video...
#
# ============================================================
# Processing: 029_1205 (4)(8)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=713, y=321, w=74, h=76
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [26/55] Processing video...
#
# ============================================================
# Processing: 045_1205 (4)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=497, y=585, w=80, h=71
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/2592 frames
#   Processed 200/2592 frames
#   Processed 300/2592 frames
#   Processed 400/2592 frames
#   Processed 500/2592 frames
#   Processed 600/2592 frames
#   Processed 700/2592 frames
#   Processed 800/2592 frames
#   Processed 900/2592 frames
#   Processed 1000/2592 frames
#   Processed 1100/2592 frames
#   Processed 1200/2592 frames
#   Processed 1300/2592 frames
#   Processed 1400/2592 frames
#   Processed 1500/2592 frames
#   Processed 1600/2592 frames
#   Processed 1700/2592 frames
#   Processed 1800/2592 frames
#   Processed 1900/2592 frames
#   Processed 2000/2592 frames
#   Processed 2100/2592 frames
#   Processed 2200/2592 frames
#   Processed 2300/2592 frames
#   Processed 2400/2592 frames
#   Processed 2500/2592 frames
# ✓ OpenCV inpainting completed
#
# [27/55] Processing video...
#
# ============================================================
# Processing: 067_1205-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=636, y=633, w=46, h=44
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/4613 frames
#   Processed 200/4613 frames
#   Processed 300/4613 frames
#   Processed 400/4613 frames
#   Processed 500/4613 frames
#   Processed 600/4613 frames
#   Processed 700/4613 frames
#   Processed 800/4613 frames
#   Processed 900/4613 frames
#   Processed 1000/4613 frames
#   Processed 1100/4613 frames
#   Processed 1200/4613 frames
#   Processed 1300/4613 frames
#   Processed 1400/4613 frames
#   Processed 1500/4613 frames
#   Processed 1600/4613 frames
#   Processed 1700/4613 frames
#   Processed 1800/4613 frames
#   Processed 1900/4613 frames
#   Processed 2000/4613 frames
#   Processed 2100/4613 frames
#   Processed 2200/4613 frames
#   Processed 2300/4613 frames
#   Processed 2400/4613 frames
#   Processed 2500/4613 frames
#   Processed 2600/4613 frames
#   Processed 2700/4613 frames
#   Processed 2800/4613 frames
#   Processed 2900/4613 frames
#   Processed 3000/4613 frames
#   Processed 3100/4613 frames
#   Processed 3200/4613 frames
#   Processed 3300/4613 frames
#   Processed 3400/4613 frames
#   Processed 3500/4613 frames
#   Processed 3600/4613 frames
#   Processed 3700/4613 frames
#   Processed 3800/4613 frames
#   Processed 3900/4613 frames
#   Processed 4000/4613 frames
#   Processed 4100/4613 frames
#   Processed 4200/4613 frames
#   Processed 4300/4613 frames
#   Processed 4400/4613 frames
#   Processed 4500/4613 frames
#   Processed 4600/4613 frames
# ✓ OpenCV inpainting completed
#
# [28/55] Processing video...
#
# ============================================================
# Processing: 049_1205-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=1002, y=632, w=48, h=51
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [29/55] Processing video...
#
# ============================================================
# Processing: 050_1205(1)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=352, y=617, w=50, h=44
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [30/55] Processing video...
#
# ============================================================
# Processing: 051_1205(2)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=651, y=625, w=56, h=56
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [31/55] Processing video...
#
# ============================================================
# Processing: 052_1205(3)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=655, y=629, w=57, h=53
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [32/55] Processing video...
#
# ============================================================
# Processing: 053_1205(4)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=660, y=201, w=55, h=54
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [33/55] Processing video...
#
# ============================================================
# Processing: 054_1205(5)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=653, y=373, w=54, h=57
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [34/55] Processing video...
#
# ============================================================
# Processing: 055_1205(6)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=657, y=622, w=53, h=58
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [35/55] Processing video...
#
# ============================================================
# Processing: 056_1205(7)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=657, y=748, w=52, h=51
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [36/55] Processing video...
#
# ============================================================
# Processing: 057_1205(8)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=787, y=479, w=16, h=15
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/376 frames
#   Processed 200/376 frames
#   Processed 300/376 frames
# ✓ OpenCV inpainting completed
#
# [37/55] Processing video...
#
# ============================================================
# Processing: 070_1205 (1)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=791, y=332, w=191, h=209
#
# Using OpenCV inpainting (fast method)...
#   Processed 100/221 frames
#   Processed 200/221 frames
# ✓ OpenCV inpainting completed
#
# [38/55] Processing video...
#
# ============================================================
# Processing: 071_1205 (1)(1)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=600, y=220, w=205, h=194
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [39/55] Processing video...
#
# ============================================================
# Processing: 072_1205 (1)(10)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=552, y=702, w=177, h=130
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [40/55] Processing video...
#
# ============================================================
# Processing: 073_1205 (1)(11)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=422, y=706, w=173, h=126
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [41/55] Processing video...
#
# ============================================================
# Processing: 074_1205 (1)(12)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=310, y=704, w=167, h=128
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [42/55] Processing video...
#
# ============================================================
# Processing: 075_1205 (1)(13)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=304, y=696, w=180, h=136
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [43/55] Processing video...
#
# ============================================================
# Processing: 076_1205 (1)(14)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=215, y=694, w=174, h=138
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [44/55] Processing video...
#
# ============================================================
# Processing: 077_1205 (1)(15)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=367, y=705, w=177, h=125
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [45/55] Processing video...
#
# ============================================================
# Processing: 078_1205 (1)(16)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=512, y=700, w=172, h=132
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [46/55] Processing video...
#
# ============================================================
# Processing: 079_1205 (1)(17)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=698, y=698, w=183, h=134
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [47/55] Processing video...
#
# ============================================================
# Processing: 080_1205 (1)(18)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=835, y=697, w=186, h=135
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [48/55] Processing video...
#
# ============================================================
# Processing: 081_1205 (1)(2)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=576, y=282, w=192, h=201
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [49/55] Processing video...
#
# ============================================================
# Processing: 082_1205 (1)(3)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=557, y=357, w=197, h=207
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [50/55] Processing video...
#
# ============================================================
# Processing: 083_1205 (1)(4)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=579, y=441, w=208, h=201
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [51/55] Processing video...
#
# ============================================================
# Processing: 084_1205 (1)(5)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=544, y=527, w=202, h=196
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [52/55] Processing video...
#
# ============================================================
# Processing: 085_1205 (1)(6)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=552, y=593, w=190, h=194
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [53/55] Processing video...
#
# ============================================================
# Processing: 086_1205 (1)(7)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=659, y=712, w=173, h=120
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [54/55] Processing video...
#
# ============================================================
# Processing: 087_1205 (1)(8)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=665, y=722, w=184, h=110
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# [55/55] Processing video...
#
# ============================================================
# Processing: 088_1205 (1)(9)-1.mp4
# ============================================================
#
# Draw a rectangle around the object to remove:
# - Click and drag to draw rectangle
# - Press 'r' to reset
# - Press ENTER when done
# - Press ESC to skip this video
#
# ROI selected: x=667, y=727, w=187, h=105
#
# Using OpenCV inpainting (fast method)...
# ✓ OpenCV inpainting completed
#
# ============================================================
# SUMMARY
# ============================================================
# Total videos: 55
# Processed: 55
# Skipped: 0
# Failed: 0
# ============================================================
