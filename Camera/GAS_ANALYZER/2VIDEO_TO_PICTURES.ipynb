# %%
import cv2
import os
from pathlib import Path

# %%
def extract_frames_from_video(video_path, output_dir):
    """Extract all frames from a video"""
    cap = cv2.VideoCapture(str(video_path))
    
    if not cap.isOpened():
        print(f"✗ Error: Cannot open video {video_path.name}")
        return False
    
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    video_folder = output_dir / video_path.stem
    video_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"Processing: {video_path.name} ({frame_count} frames)")
    
    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_filename = video_folder / f"frame_{frame_idx:05d}.jpg"
        cv2.imwrite(str(frame_filename), frame, [cv2.IMWRITE_JPEG_QUALITY, 95])
        
        frame_idx += 1
        if frame_idx % 100 == 0:
            print(f"  Extracted {frame_idx}/{frame_count} frames")
    
    cap.release()
    print(f"✓ Completed: {frame_idx} frames saved to {video_folder}\n")
    return True

# %%
def process_video_directory(input_dir, output_dir):
    """Process all videos from a single input directory"""
    input_path = Path(input_dir)
    output_path = Path(output_dir)
    
    if not input_path.exists():
        print(f"⚠️ Directory not found: {input_dir}")
        return 0, 0
    
    output_path.mkdir(parents=True, exist_ok=True)
    
    video_extensions = ['.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv']
    videos = []
    
    for ext in video_extensions:
        videos.extend(input_path.rglob(f'*{ext}'))
    
    if not videos:
        print(f"No video files found in {input_dir}")
        return 0, 0
    
    print(f"\nProcessing {len(videos)} videos from: {input_dir}")
    print(f"Output directory: {output_dir}")
    print("="*60)
    
    processed = 0
    failed = 0
    
    for idx, video_path in enumerate(videos, 1):
        print(f"\n[{idx}/{len(videos)}]")
        
        success = extract_frames_from_video(video_path, output_path)
        
        if success:
            processed += 1
        else:
            failed += 1
    
    return processed, failed

# %%
# Input and output directories
NO_DETECTOR_INPUT = r"C:\Users\thaim\Videos\AI_LEDS\NO_detector"
NO_DETECTOR_OUTPUT = r"C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures"

DETECTOR_INPUT = r"C:\Users\thaim\Videos\AI_LEDS\DETECTOR"
DETECTOR_OUTPUT = r"C:\Users\thaim\Videos\AI_LEDS\detector_pictures"

# Process both directories
print("\n" + "="*60)
print("PROCESSING NO_DETECTOR VIDEOS")
print("="*60)
no_det_processed, no_det_failed = process_video_directory(NO_DETECTOR_INPUT, NO_DETECTOR_OUTPUT)

print("\n" + "="*60)
print("PROCESSING DETECTOR VIDEOS")
print("="*60)
det_processed, det_failed = process_video_directory(DETECTOR_INPUT, DETECTOR_OUTPUT)

# Overall summary
print("\n" + "="*60)
print("OVERALL SUMMARY")
print("="*60)
print(f"No detector videos - Processed: {no_det_processed}, Failed: {no_det_failed}")
print(f"Detector videos - Processed: {det_processed}, Failed: {det_failed}")
print(f"Total - Processed: {no_det_processed + det_processed}, Failed: {no_det_failed + det_failed}")
print("="*60)
# Out:
# ============================================================
# PROCESSING NO_DETECTOR VIDEOS
# ============================================================
#
# Processing 40 videos from: C:\Users\thaim\Videos\AI_LEDS\NO_detector
# Output directory: C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures
# ============================================================
#
# [1/40]
# Processing: 005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf.mp4 (1917 frames)
#   Extracted 100/1917 frames
#   Extracted 200/1917 frames
#   Extracted 300/1917 frames
#   Extracted 400/1917 frames
#   Extracted 500/1917 frames
#   Extracted 600/1917 frames
#   Extracted 700/1917 frames
#   Extracted 800/1917 frames
#   Extracted 900/1917 frames
#   Extracted 1000/1917 frames
#   Extracted 1100/1917 frames
#   Extracted 1200/1917 frames
#   Extracted 1300/1917 frames
#   Extracted 1400/1917 frames
#   Extracted 1500/1917 frames
#   Extracted 1600/1917 frames
#   Extracted 1700/1917 frames
#   Extracted 1800/1917 frames
#   Extracted 1900/1917 frames
# ✓ Completed: 1917 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf
#
#
# [2/40]
# Processing: 006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf.mp4 (296 frames)
#   Extracted 100/296 frames
#   Extracted 200/296 frames
# ✓ Completed: 296 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf
#
#
# [3/40]
# Processing: 007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn.mp4 (1146 frames)
#   Extracted 100/1146 frames
#   Extracted 200/1146 frames
#   Extracted 300/1146 frames
#   Extracted 400/1146 frames
#   Extracted 500/1146 frames
#   Extracted 600/1146 frames
#   Extracted 700/1146 frames
#   Extracted 800/1146 frames
#   Extracted 900/1146 frames
#   Extracted 1000/1146 frames
#   Extracted 1100/1146 frames
# ✓ Completed: 1146 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn
#
#
# [4/40]
# Processing: 008_40_lmalh_zvvyt_ymynh.mp4 (1211 frames)
#   Extracted 100/1211 frames
#   Extracted 200/1211 frames
#   Extracted 300/1211 frames
#   Extracted 400/1211 frames
#   Extracted 500/1211 frames
#   Extracted 600/1211 frames
#   Extracted 700/1211 frames
#   Extracted 800/1211 frames
#   Extracted 900/1211 frames
#   Extracted 1000/1211 frames
#   Extracted 1100/1211 frames
#   Extracted 1200/1211 frames
# ✓ Completed: 1211 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\008_40_lmalh_zvvyt_ymynh
#
#
# [5/40]
# Processing: 009_40_rtz.mp4 (487 frames)
#   Extracted 100/487 frames
#   Extracted 200/487 frames
#   Extracted 300/487 frames
#   Extracted 400/487 frames
# ✓ Completed: 487 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\009_40_rtz
#
#
# [6/40]
# Processing: 010_40_ymynh_lmth.mp4 (169 frames)
#   Extracted 100/169 frames
# ✓ Completed: 169 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\010_40_ymynh_lmth
#
#
# [7/40]
# Processing: 011_50_zvvyt_ymynh.mp4 (563 frames)
#   Extracted 100/563 frames
#   Extracted 200/563 frames
#   Extracted 300/563 frames
#   Extracted 400/563 frames
#   Extracted 500/563 frames
# ✓ Completed: 563 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\011_50_zvvyt_ymynh
#
#
# [8/40]
# Processing: 012_rtz_50.mp4 (390 frames)
#   Extracted 100/390 frames
#   Extracted 200/390 frames
#   Extracted 300/390 frames
# ✓ Completed: 390 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\012_rtz_50
#
#
# [9/40]
# Processing: 013_zvvyt_lmalh_50.mp4 (376 frames)
#   Extracted 100/376 frames
#   Extracted 200/376 frames
#   Extracted 300/376 frames
# ✓ Completed: 376 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\013_zvvyt_lmalh_50
#
#
# [10/40]
# Processing: 014_zvvyt_lmth_50.mp4 (310 frames)
#   Extracted 100/310 frames
#   Extracted 200/310 frames
#   Extracted 300/310 frames
# ✓ Completed: 310 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\014_zvvyt_lmth_50
#
#
# [11/40]
# Processing: 015_zvvyt_shmalh_50.mp4 (374 frames)
#   Extracted 100/374 frames
#   Extracted 200/374 frames
#   Extracted 300/374 frames
# ✓ Completed: 374 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\015_zvvyt_shmalh_50
#
#
# [12/40]
# Processing: 001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1.mp4 (708 frames)
#   Extracted 100/708 frames
#   Extracted 200/708 frames
#   Extracted 300/708 frames
#   Extracted 400/708 frames
#   Extracted 500/708 frames
#   Extracted 600/708 frames
#   Extracted 700/708 frames
# ✓ Completed: 708 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1
#
#
# [13/40]
# Processing: 002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1.mp4 (908 frames)
#   Extracted 100/908 frames
#   Extracted 200/908 frames
#   Extracted 300/908 frames
#   Extracted 400/908 frames
#   Extracted 500/908 frames
#   Extracted 600/908 frames
#   Extracted 700/908 frames
#   Extracted 800/908 frames
#   Extracted 900/908 frames
# ✓ Completed: 908 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1
#
#
# [14/40]
# Processing: 017_1205 (4)-1.mp4 (88 frames)
# ✓ Completed: 88 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\017_1205 (4)-1
#
#
# [15/40]
# Processing: 018_1205 (4)(1)-1.mp4 (100 frames)
#   Extracted 100/100 frames
# ✓ Completed: 100 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\018_1205 (4)(1)-1
#
#
# [16/40]
# Processing: 020_1205 (4)(11)-1.mp4 (51 frames)
# ✓ Completed: 51 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\020_1205 (4)(11)-1
#
#
# [17/40]
# Processing: 023_1205 (4)(2)-1.mp4 (70 frames)
# ✓ Completed: 70 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\023_1205 (4)(2)-1
#
#
# [18/40]
# Processing: 024_1205 (4)(3)-1.mp4 (288 frames)
#   Extracted 100/288 frames
#   Extracted 200/288 frames
# ✓ Completed: 288 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\024_1205 (4)(3)-1
#
#
# [19/40]
# Processing: 025_1205 (4)(4)-1.mp4 (133 frames)
#   Extracted 100/133 frames
# ✓ Completed: 133 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\025_1205 (4)(4)-1
#
#
# [20/40]
# Processing: 026_1205 (4)(5)-1.mp4 (49 frames)
# ✓ Completed: 49 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\026_1205 (4)(5)-1
#
#
# [21/40]
# Processing: 027_1205 (4)(6)-1.mp4 (33 frames)
# ✓ Completed: 33 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\027_1205 (4)(6)-1
#
#
# [22/40]
# Processing: 028_1205 (4)(7)-1.mp4 (36 frames)
# ✓ Completed: 36 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\028_1205 (4)(7)-1
#
#
# [23/40]
# Processing: 029_1205 (4)(8)-1.mp4 (40 frames)
# ✓ Completed: 40 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\029_1205 (4)(8)-1
#
#
# [24/40]
# Processing: 045_1205 (4)-1.mp4 (2592 frames)
#   Extracted 100/2592 frames
#   Extracted 200/2592 frames
#   Extracted 300/2592 frames
#   Extracted 400/2592 frames
#   Extracted 500/2592 frames
#   Extracted 600/2592 frames
#   Extracted 700/2592 frames
#   Extracted 800/2592 frames
#   Extracted 900/2592 frames
#   Extracted 1000/2592 frames
#   Extracted 1100/2592 frames
#   Extracted 1200/2592 frames
#   Extracted 1300/2592 frames
#   Extracted 1400/2592 frames
#   Extracted 1500/2592 frames
#   Extracted 1600/2592 frames
#   Extracted 1700/2592 frames
#   Extracted 1800/2592 frames
#   Extracted 1900/2592 frames
#   Extracted 2000/2592 frames
#   Extracted 2100/2592 frames
#   Extracted 2200/2592 frames
#   Extracted 2300/2592 frames
#   Extracted 2400/2592 frames
#   Extracted 2500/2592 frames
# ✓ Completed: 2592 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\045_1205 (4)-1
#
#
# [25/40]
# Processing: 067_1205-1.mp4 (4613 frames)
#   Extracted 100/4613 frames
#   Extracted 200/4613 frames
#   Extracted 300/4613 frames
#   Extracted 400/4613 frames
#   Extracted 500/4613 frames
#   Extracted 600/4613 frames
#   Extracted 700/4613 frames
#   Extracted 800/4613 frames
#   Extracted 900/4613 frames
#   Extracted 1000/4613 frames
#   Extracted 1100/4613 frames
#   Extracted 1200/4613 frames
#   Extracted 1300/4613 frames
#   Extracted 1400/4613 frames
#   Extracted 1500/4613 frames
#   Extracted 1600/4613 frames
#   Extracted 1700/4613 frames
#   Extracted 1800/4613 frames
#   Extracted 1900/4613 frames
#   Extracted 2000/4613 frames
#   Extracted 2100/4613 frames
#   Extracted 2200/4613 frames
#   Extracted 2300/4613 frames
#   Extracted 2400/4613 frames
#   Extracted 2500/4613 frames
#   Extracted 2600/4613 frames
#   Extracted 2700/4613 frames
#   Extracted 2800/4613 frames
#   Extracted 2900/4613 frames
#   Extracted 3000/4613 frames
#   Extracted 3100/4613 frames
#   Extracted 3200/4613 frames
#   Extracted 3300/4613 frames
#   Extracted 3400/4613 frames
#   Extracted 3500/4613 frames
#   Extracted 3600/4613 frames
#   Extracted 3700/4613 frames
#   Extracted 3800/4613 frames
#   Extracted 3900/4613 frames
#   Extracted 4000/4613 frames
#   Extracted 4100/4613 frames
#   Extracted 4200/4613 frames
#   Extracted 4300/4613 frames
#   Extracted 4400/4613 frames
#   Extracted 4500/4613 frames
#   Extracted 4600/4613 frames
# ✓ Completed: 4613 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\067_1205-1
#
#
# [26/40]
# Processing: 049_1205-1.mp4 (40 frames)
# ✓ Completed: 40 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\049_1205-1
#
#
# [27/40]
# Processing: 050_1205(1)-1.mp4 (33 frames)
# ✓ Completed: 33 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\050_1205(1)-1
#
#
# [28/40]
# Processing: 051_1205(2)-1.mp4 (55 frames)
# ✓ Completed: 55 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\051_1205(2)-1
#
#
# [29/40]
# Processing: 052_1205(3)-1.mp4 (18 frames)
# ✓ Completed: 18 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\052_1205(3)-1
#
#
# [30/40]
# Processing: 053_1205(4)-1.mp4 (10 frames)
# ✓ Completed: 10 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\053_1205(4)-1
#
#
# [31/40]
# Processing: 054_1205(5)-1.mp4 (18 frames)
# ✓ Completed: 18 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\054_1205(5)-1
#
#
# [32/40]
# Processing: 055_1205(6)-1.mp4 (16 frames)
# ✓ Completed: 16 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\055_1205(6)-1
#
#
# [33/40]
# Processing: 056_1205(7)-1.mp4 (27 frames)
# ✓ Completed: 27 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\056_1205(7)-1
#
#
# [34/40]
# Processing: 070_1205 (1)-1.mp4 (221 frames)
#   Extracted 100/221 frames
#   Extracted 200/221 frames
# ✓ Completed: 221 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\070_1205 (1)-1
#
#
# [35/40]
# Processing: 071_1205 (1)(1)-1.mp4 (15 frames)
# ✓ Completed: 15 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\071_1205 (1)(1)-1
#
#
# [36/40]
# Processing: 081_1205 (1)(2)-1.mp4 (18 frames)
# ✓ Completed: 18 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\081_1205 (1)(2)-1
#
#
# [37/40]
# Processing: 082_1205 (1)(3)-1.mp4 (16 frames)
# ✓ Completed: 16 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\082_1205 (1)(3)-1
#
#
# [38/40]
# Processing: 083_1205 (1)(4)-1.mp4 (27 frames)
# ✓ Completed: 27 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\083_1205 (1)(4)-1
#
#
# [39/40]
# Processing: 084_1205 (1)(5)-1.mp4 (42 frames)
# ✓ Completed: 42 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\084_1205 (1)(5)-1
#
#
# [40/40]
# Processing: 085_1205 (1)(6)-1.mp4 (19 frames)
# ✓ Completed: 19 frames saved to C:\Users\thaim\Videos\AI_LEDS\no_detector_pictures\085_1205 (1)(6)-1
#
#
# ============================================================
# PROCESSING DETECTOR VIDEOS
# ============================================================
#
# Processing 67 videos from: C:\Users\thaim\Videos\AI_LEDS\DETECTOR
# Output directory: C:\Users\thaim\Videos\AI_LEDS\detector_pictures
# ============================================================
#
# [1/67]
# Processing: 005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf.mp4 (1917 frames)
#   Extracted 100/1917 frames
#   Extracted 200/1917 frames
#   Extracted 300/1917 frames
#   Extracted 400/1917 frames
#   Extracted 500/1917 frames
#   Extracted 600/1917 frames
#   Extracted 700/1917 frames
#   Extracted 800/1917 frames
#   Extracted 900/1917 frames
#   Extracted 1000/1917 frames
#   Extracted 1100/1917 frames
#   Extracted 1200/1917 frames
#   Extracted 1300/1917 frames
#   Extracted 1400/1917 frames
#   Extracted 1500/1917 frames
#   Extracted 1600/1917 frames
#   Extracted 1700/1917 frames
#   Extracted 1800/1917 frames
#   Extracted 1900/1917 frames
# ✓ Completed: 1917 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\005_30_rgyl_ayn_shmsh_ldym_mkdymh_rka_shkvf
#
#
# [2/67]
# Processing: 006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf.mp4 (296 frames)
#   Extracted 100/296 frames
#   Extracted 200/296 frames
# ✓ Completed: 296 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\006_30_zvvyt_ymynh_ayn_shmsh_ldym_mkdymh_rka_shkvf
#
#
# [3/67]
# Processing: 007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn.mp4 (1146 frames)
#   Extracted 100/1146 frames
#   Extracted 200/1146 frames
#   Extracted 300/1146 frames
#   Extracted 400/1146 frames
#   Extracted 500/1146 frames
#   Extracted 600/1146 frames
#   Extracted 700/1146 frames
#   Extracted 800/1146 frames
#   Extracted 900/1146 frames
#   Extracted 1000/1146 frames
#   Extracted 1100/1146 frames
# ✓ Completed: 1146 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\007_30_zvvyvt_lmth_lashvt_arykh_lsrtvn
#
#
# [4/67]
# Processing: 008_40_lmalh_zvvyt_ymynh.mp4 (1211 frames)
#   Extracted 100/1211 frames
#   Extracted 200/1211 frames
#   Extracted 300/1211 frames
#   Extracted 400/1211 frames
#   Extracted 500/1211 frames
#   Extracted 600/1211 frames
#   Extracted 700/1211 frames
#   Extracted 800/1211 frames
#   Extracted 900/1211 frames
#   Extracted 1000/1211 frames
#   Extracted 1100/1211 frames
#   Extracted 1200/1211 frames
# ✓ Completed: 1211 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\008_40_lmalh_zvvyt_ymynh
#
#
# [5/67]
# Processing: 009_40_rtz.mp4 (487 frames)
#   Extracted 100/487 frames
#   Extracted 200/487 frames
#   Extracted 300/487 frames
#   Extracted 400/487 frames
# ✓ Completed: 487 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\009_40_rtz
#
#
# [6/67]
# Processing: 010_40_ymynh_lmth.mp4 (169 frames)
#   Extracted 100/169 frames
# ✓ Completed: 169 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\010_40_ymynh_lmth
#
#
# [7/67]
# Processing: 011_50_zvvyt_ymynh.mp4 (563 frames)
#   Extracted 100/563 frames
#   Extracted 200/563 frames
#   Extracted 300/563 frames
#   Extracted 400/563 frames
#   Extracted 500/563 frames
# ✓ Completed: 563 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\011_50_zvvyt_ymynh
#
#
# [8/67]
# Processing: 012_rtz_50.mp4 (390 frames)
#   Extracted 100/390 frames
#   Extracted 200/390 frames
#   Extracted 300/390 frames
# ✓ Completed: 390 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\012_rtz_50
#
#
# [9/67]
# Processing: 013_zvvyt_lmalh_50.mp4 (376 frames)
#   Extracted 100/376 frames
#   Extracted 200/376 frames
#   Extracted 300/376 frames
# ✓ Completed: 376 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\013_zvvyt_lmalh_50
#
#
# [10/67]
# Processing: 014_zvvyt_lmth_50.mp4 (310 frames)
#   Extracted 100/310 frames
#   Extracted 200/310 frames
#   Extracted 300/310 frames
# ✓ Completed: 310 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\014_zvvyt_lmth_50
#
#
# [11/67]
# Processing: 015_zvvyt_shmalh_50.mp4 (374 frames)
#   Extracted 100/374 frames
#   Extracted 200/374 frames
#   Extracted 300/374 frames
# ✓ Completed: 374 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\015_zvvyt_shmalh_50
#
#
# [12/67]
# Processing: 001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1.mp4 (708 frames)
#   Extracted 100/708 frames
#   Extracted 200/708 frames
#   Extracted 300/708 frames
#   Extracted 400/708 frames
#   Extracted 500/708 frames
#   Extracted 600/708 frames
#   Extracted 700/708 frames
# ✓ Completed: 708 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\001_40_mtr_rka_la_shchvr_3_ldym_shmalh_1
#
#
# [13/67]
# Processing: 002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1.mp4 (908 frames)
#   Extracted 100/908 frames
#   Extracted 200/908 frames
#   Extracted 300/908 frames
#   Extracted 400/908 frames
#   Extracted 500/908 frames
#   Extracted 600/908 frames
#   Extracted 700/908 frames
#   Extracted 800/908 frames
#   Extracted 900/908 frames
# ✓ Completed: 908 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\002_rka_shchvr_lglay_40_mtr_shmalh_3_ldym_1
#
#
# [14/67]
# Processing: 017_1205 (4)-1.mp4 (88 frames)
# ✓ Completed: 88 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\017_1205 (4)-1
#
#
# [15/67]
# Processing: 018_1205 (4)(1)-1.mp4 (100 frames)
#   Extracted 100/100 frames
# ✓ Completed: 100 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\018_1205 (4)(1)-1
#
#
# [16/67]
# Processing: 020_1205 (4)(11)-1.mp4 (51 frames)
# ✓ Completed: 51 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\020_1205 (4)(11)-1
#
#
# [17/67]
# Processing: 021_1205 (4)(12)-1.mp4 (127 frames)
#   Extracted 100/127 frames
# ✓ Completed: 127 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\021_1205 (4)(12)-1
#
#
# [18/67]
# Processing: 022_1205 (4)(13)-1.mp4 (131 frames)
#   Extracted 100/131 frames
# ✓ Completed: 131 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\022_1205 (4)(13)-1
#
#
# [19/67]
# Processing: 023_1205 (4)(2)-1.mp4 (70 frames)
# ✓ Completed: 70 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\023_1205 (4)(2)-1
#
#
# [20/67]
# Processing: 024_1205 (4)(3)-1.mp4 (288 frames)
#   Extracted 100/288 frames
#   Extracted 200/288 frames
# ✓ Completed: 288 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\024_1205 (4)(3)-1
#
#
# [21/67]
# Processing: 025_1205 (4)(4)-1.mp4 (133 frames)
#   Extracted 100/133 frames
# ✓ Completed: 133 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\025_1205 (4)(4)-1
#
#
# [22/67]
# Processing: 026_1205 (4)(5)-1.mp4 (49 frames)
# ✓ Completed: 49 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\026_1205 (4)(5)-1
#
#
# [23/67]
# Processing: 027_1205 (4)(6)-1.mp4 (33 frames)
# ✓ Completed: 33 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\027_1205 (4)(6)-1
#
#
# [24/67]
# Processing: 028_1205 (4)(7)-1.mp4 (36 frames)
# ✓ Completed: 36 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\028_1205 (4)(7)-1
#
#
# [25/67]
# Processing: 029_1205 (4)(8)-1.mp4 (40 frames)
# ✓ Completed: 40 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\029_1205 (4)(8)-1
#
#
# [26/67]
# Processing: 045_1205 (4)-1.mp4 (2592 frames)
#   Extracted 100/2592 frames
#   Extracted 200/2592 frames
#   Extracted 300/2592 frames
#   Extracted 400/2592 frames
#   Extracted 500/2592 frames
#   Extracted 600/2592 frames
#   Extracted 700/2592 frames
#   Extracted 800/2592 frames
#   Extracted 900/2592 frames
#   Extracted 1000/2592 frames
#   Extracted 1100/2592 frames
#   Extracted 1200/2592 frames
#   Extracted 1300/2592 frames
#   Extracted 1400/2592 frames
#   Extracted 1500/2592 frames
#   Extracted 1600/2592 frames
#   Extracted 1700/2592 frames
#   Extracted 1800/2592 frames
#   Extracted 1900/2592 frames
#   Extracted 2000/2592 frames
#   Extracted 2100/2592 frames
#   Extracted 2200/2592 frames
#   Extracted 2300/2592 frames
#   Extracted 2400/2592 frames
#   Extracted 2500/2592 frames
# ✓ Completed: 2592 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\045_1205 (4)-1
#
#
# [27/67]
# Processing: 067_1205-1.mp4 (4613 frames)
#   Extracted 100/4613 frames
#   Extracted 200/4613 frames
#   Extracted 300/4613 frames
#   Extracted 400/4613 frames
#   Extracted 500/4613 frames
#   Extracted 600/4613 frames
#   Extracted 700/4613 frames
#   Extracted 800/4613 frames
#   Extracted 900/4613 frames
#   Extracted 1000/4613 frames
#   Extracted 1100/4613 frames
#   Extracted 1200/4613 frames
#   Extracted 1300/4613 frames
#   Extracted 1400/4613 frames
#   Extracted 1500/4613 frames
#   Extracted 1600/4613 frames
#   Extracted 1700/4613 frames
#   Extracted 1800/4613 frames
#   Extracted 1900/4613 frames
#   Extracted 2000/4613 frames
#   Extracted 2100/4613 frames
#   Extracted 2200/4613 frames
#   Extracted 2300/4613 frames
#   Extracted 2400/4613 frames
#   Extracted 2500/4613 frames
#   Extracted 2600/4613 frames
#   Extracted 2700/4613 frames
#   Extracted 2800/4613 frames
#   Extracted 2900/4613 frames
#   Extracted 3000/4613 frames
#   Extracted 3100/4613 frames
#   Extracted 3200/4613 frames
#   Extracted 3300/4613 frames
#   Extracted 3400/4613 frames
#   Extracted 3500/4613 frames
#   Extracted 3600/4613 frames
#   Extracted 3700/4613 frames
#   Extracted 3800/4613 frames
#   Extracted 3900/4613 frames
#   Extracted 4000/4613 frames
#   Extracted 4100/4613 frames
#   Extracted 4200/4613 frames
#   Extracted 4300/4613 frames
#   Extracted 4400/4613 frames
#   Extracted 4500/4613 frames
#   Extracted 4600/4613 frames
# ✓ Completed: 4613 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\067_1205-1
#
#
# [28/67]
# Processing: 049_1205-1.mp4 (40 frames)
# ✓ Completed: 40 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\049_1205-1
#
#
# [29/67]
# Processing: 050_1205(1)-1.mp4 (33 frames)
# ✓ Completed: 33 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\050_1205(1)-1
#
#
# [30/67]
# Processing: 051_1205(2)-1.mp4 (55 frames)
# ✓ Completed: 55 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\051_1205(2)-1
#
#
# [31/67]
# Processing: 052_1205(3)-1.mp4 (18 frames)
# ✓ Completed: 18 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\052_1205(3)-1
#
#
# [32/67]
# Processing: 053_1205(4)-1.mp4 (10 frames)
# ✓ Completed: 10 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\053_1205(4)-1
#
#
# [33/67]
# Processing: 054_1205(5)-1.mp4 (18 frames)
# ✓ Completed: 18 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\054_1205(5)-1
#
#
# [34/67]
# Processing: 055_1205(6)-1.mp4 (16 frames)
# ✓ Completed: 16 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\055_1205(6)-1
#
#
# [35/67]
# Processing: 056_1205(7)-1.mp4 (27 frames)
# ✓ Completed: 27 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\056_1205(7)-1
#
#
# [36/67]
# Processing: 057_1205(8)-1.mp4 (376 frames)
#   Extracted 100/376 frames
#   Extracted 200/376 frames
#   Extracted 300/376 frames
# ✓ Completed: 376 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\057_1205(8)-1
#
#
# [37/67]
# Processing: 070_1205 (1)-1.mp4 (221 frames)
#   Extracted 100/221 frames
#   Extracted 200/221 frames
# ✓ Completed: 221 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\070_1205 (1)-1
#
#
# [38/67]
# Processing: 071_1205 (1)(1)-1.mp4 (15 frames)
# ✓ Completed: 15 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\071_1205 (1)(1)-1
#
#
# [39/67]
# Processing: 072_1205 (1)(10)-1.mp4 (25 frames)
# ✓ Completed: 25 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\072_1205 (1)(10)-1
#
#
# [40/67]
# Processing: 073_1205 (1)(11)-1.mp4 (39 frames)
# ✓ Completed: 39 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\073_1205 (1)(11)-1
#
#
# [41/67]
# Processing: 074_1205 (1)(12)-1.mp4 (24 frames)
# ✓ Completed: 24 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\074_1205 (1)(12)-1
#
#
# [42/67]
# Processing: 075_1205 (1)(13)-1.mp4 (35 frames)
# ✓ Completed: 35 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\075_1205 (1)(13)-1
#
#
# [43/67]
# Processing: 076_1205 (1)(14)-1.mp4 (53 frames)
# ✓ Completed: 53 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\076_1205 (1)(14)-1
#
#
# [44/67]
# Processing: 077_1205 (1)(15)-1.mp4 (48 frames)
# ✓ Completed: 48 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\077_1205 (1)(15)-1
#
#
# [45/67]
# Processing: 078_1205 (1)(16)-1.mp4 (29 frames)
# ✓ Completed: 29 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\078_1205 (1)(16)-1
#
#
# [46/67]
# Processing: 079_1205 (1)(17)-1.mp4 (45 frames)
# ✓ Completed: 45 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\079_1205 (1)(17)-1
#
#
# [47/67]
# Processing: 080_1205 (1)(18)-1.mp4 (53 frames)
# ✓ Completed: 53 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\080_1205 (1)(18)-1
#
#
# [48/67]
# Processing: 081_1205 (1)(2)-1.mp4 (18 frames)
# ✓ Completed: 18 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\081_1205 (1)(2)-1
#
#
# [49/67]
# Processing: 082_1205 (1)(3)-1.mp4 (16 frames)
# ✓ Completed: 16 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\082_1205 (1)(3)-1
#
#
# [50/67]
# Processing: 083_1205 (1)(4)-1.mp4 (27 frames)
# ✓ Completed: 27 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\083_1205 (1)(4)-1
#
#
# [51/67]
# Processing: 084_1205 (1)(5)-1.mp4 (42 frames)
# ✓ Completed: 42 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\084_1205 (1)(5)-1
#
#
# [52/67]
# Processing: 085_1205 (1)(6)-1.mp4 (19 frames)
# ✓ Completed: 19 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\085_1205 (1)(6)-1
#
#
# [53/67]
# Processing: 086_1205 (1)(7)-1.mp4 (27 frames)
# ✓ Completed: 27 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\086_1205 (1)(7)-1
#
#
# [54/67]
# Processing: 087_1205 (1)(8)-1.mp4 (43 frames)
# ✓ Completed: 43 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\087_1205 (1)(8)-1
#
#
# [55/67]
# Processing: 088_1205 (1)(9)-1.mp4 (44 frames)
# ✓ Completed: 44 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\088_1205 (1)(9)-1
#
#
# [56/67]
# Processing: 072_1205 (1)(10)-1.mp4 (25 frames)
# ✓ Completed: 25 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\072_1205 (1)(10)-1
#
#
# [57/67]
# Processing: 073_1205 (1)(11)-1.mp4 (39 frames)
# ✓ Completed: 39 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\073_1205 (1)(11)-1
#
#
# [58/67]
# Processing: 074_1205 (1)(12)-1.mp4 (24 frames)
# ✓ Completed: 24 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\074_1205 (1)(12)-1
#
#
# [59/67]
# Processing: 075_1205 (1)(13)-1.mp4 (35 frames)
# ✓ Completed: 35 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\075_1205 (1)(13)-1
#
#
# [60/67]
# Processing: 076_1205 (1)(14)-1.mp4 (53 frames)
# ✓ Completed: 53 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\076_1205 (1)(14)-1
#
#
# [61/67]
# Processing: 077_1205 (1)(15)-1.mp4 (48 frames)
# ✓ Completed: 48 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\077_1205 (1)(15)-1
#
#
# [62/67]
# Processing: 078_1205 (1)(16)-1.mp4 (29 frames)
# ✓ Completed: 29 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\078_1205 (1)(16)-1
#
#
# [63/67]
# Processing: 079_1205 (1)(17)-1.mp4 (45 frames)
# ✓ Completed: 45 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\079_1205 (1)(17)-1
#
#
# [64/67]
# Processing: 080_1205 (1)(18)-1.mp4 (53 frames)
# ✓ Completed: 53 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\080_1205 (1)(18)-1
#
#
# [65/67]
# Processing: 086_1205 (1)(7)-1.mp4 (27 frames)
# ✓ Completed: 27 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\086_1205 (1)(7)-1
#
#
# [66/67]
# Processing: 087_1205 (1)(8)-1.mp4 (43 frames)
# ✓ Completed: 43 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\087_1205 (1)(8)-1
#
#
# [67/67]
# Processing: 088_1205 (1)(9)-1.mp4 (44 frames)
# ✓ Completed: 44 frames saved to C:\Users\thaim\Videos\AI_LEDS\detector_pictures\088_1205 (1)(9)-1
#
#
# ============================================================
# OVERALL SUMMARY
# ============================================================
# No detector videos - Processed: 40, Failed: 0
# Detector videos - Processed: 67, Failed: 0
# Total - Processed: 107, Failed: 0
# ============================================================
