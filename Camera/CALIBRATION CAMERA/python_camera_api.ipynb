# %% [markdown]
# # SPECIFIC CAMERA

# %%
# Purpose: Single IDS specific camera calibration GUI cell (includes GENICAM setup and optional edge mode).
import os
import glob
import json
from collections import deque
from datetime import datetime

import cv2
import numpy as np
from ids_peak import ids_peak
from ids_peak_ipl import ids_peak_ipl

# Purpose: Configure GENICAM_GENTL64_PATH so IDS Peak finds CTI files.
PEAK_CTI_HINT = None  # Example: r"C:\\Program Files\\IDS\\ids_peak\\generic_sdk\\api\\bin\\x86_64"
def _ensure_gentl_path():
    existing = os.environ.get("GENICAM_GENTL64_PATH", "")
    if existing:
        existing_paths = [p for p in existing.split(";") if p]
        if any(os.path.isdir(p) and glob.glob(os.path.join(p, "*.cti")) for p in existing_paths):
            return

    found = []
    if PEAK_CTI_HINT and os.path.isdir(PEAK_CTI_HINT) and glob.glob(os.path.join(PEAK_CTI_HINT, "*.cti")):
        found.append(PEAK_CTI_HINT)

    candidates = [r"C:\\Program Files\\IDS\\ids_peak", r"C:\\Program Files\\IDS"]
    for root in candidates:
        if not os.path.isdir(root):
            continue
        for d in glob.glob(os.path.join(root, "**"), recursive=True):
            if os.path.isdir(d) and glob.glob(os.path.join(d, "*.cti")):
                found.append(d)

    if not found:
        raise RuntimeError("GENICAM_GENTL64_PATH not found. Set it to a valid IDS CTI directory.")

    uniq = []
    seen = set()
    for d in found:
        if d not in seen:
            seen.add(d)
            uniq.append(d)
    os.environ["GENICAM_GENTL64_PATH"] = ";".join(uniq)

_ensure_gentl_path()

# Purpose: Shared window names and edge parameters.
WINDOW_NAME = "IDS Peak - Calibration & Control"
CONTROL_WINDOW_NAME = "Control Panel"
EDGE_CANNY_LOW = 80
EDGE_CANNY_HIGH = 180

# Purpose: Main state for circles and crop interactions.
circle_state = {
    "center": None,
    "radius": 30,
    "dragging": False,
    "pixel_per_meter": None,
    "ref_center": None,
    "ref_radius": 100,
    "ref_dragging": False,
    "show_circles": True,
    "control_target": "main",
    "crop_mode": False,
    "crop_active": False,
    "crop_roi": None,
    "crop_selecting": False,
    "crop_start": None,
    "crop_current": None,
}

# Purpose: Cache last-applied camera controls so nodes update only when changed.
camera_controls = {
    "brightness": 100,
    "exposure": 5000,
    "analog_gain": 0,
    "digital_gain": 10,
}

# Purpose: Small status queue for overlay messages.
status_messages = deque(maxlen=5)

# Purpose: Runtime UI state for buttons, display mapping, and side-panel controls.
ui_state = {
    "buttons": {
        "crop": (10, 10, 110, 42),
        "home": (120, 10, 220, 42),
        "edges": (230, 10, 350, 42),
    },
    "display_map": None,
    "prompt_save_name": False,
    "edge_mode": 0,
    "show_measure": 0,
    "show_notes": 1,
    "controls": {
        "brightness": 100,
        "exposure": 5000,
        "analog_gain": 0,
        "digital_gain_x10": 10,
        "edge_low": EDGE_CANNY_LOW,
        "edge_high": EDGE_CANNY_HIGH,
        "main_radius": 30,
        "ref_radius": 100,
        "main_cx": 640,
        "main_cy": 480,
        "ref_cx": 700,
        "ref_cy": 480,
    },
    "control_widgets": {},
    "control_drag": None,
    "controls_dirty": False,
    "active_value_edit": None,
    "value_edit_buffer": "",
}

# Purpose: Folder for displayed-frame screenshots.
SCREENSHOT_DIR = os.path.join(os.getcwd(), "ids_specific_camera_shots")
os.makedirs(SCREENSHOT_DIR, exist_ok=True)

# Purpose: Add one short status message.
def add_status_message(msg):
    status_messages.append(str(msg))

def _point_in_rect(x, y, rect):
    x1, y1, x2, y2 = rect
    return x1 <= x <= x2 and y1 <= y <= y2

def _move_selected_circle(dx, dy, frame_w, frame_h):
    key = "center" if circle_state.get("control_target", "main") == "main" else "ref_center"
    center = circle_state.get(key)
    if center is None:
        return
    nx = max(0, min(frame_w - 1, int(center[0] + dx)))
    ny = max(0, min(frame_h - 1, int(center[1] + dy)))
    circle_state[key] = (nx, ny)

def _safe_name_token(text, default):
    token = str(text).strip().replace(" ", "-")
    token = "".join(ch for ch in token if ch.isalnum() or ch in ("-", "_"))
    return token if token else default

def _prompt_shot_stem(timestamp):
    cube_number = _safe_name_token(input("Cube number: "), "cube")
    cube_position = _safe_name_token(input("Cube position: "), "pos")
    return f"{cube_number}_{cube_position}_{timestamp}"

def _adjust_target_radius(delta):
    controls = ui_state["controls"]
    if circle_state.get("control_target", "main") == "main":
        controls["main_radius"] = max(1, min(200, int(controls["main_radius"]) + int(delta)))
        circle_state["radius"] = int(controls["main_radius"])
    else:
        controls["ref_radius"] = max(1, min(500, int(controls["ref_radius"]) + int(delta)))
        circle_state["ref_radius"] = int(controls["ref_radius"])
    ui_state["controls_dirty"] = True

def _control_specs(frame_w, frame_h):
    max_x = max(0, int(frame_w) - 1)
    max_y = max(0, int(frame_h) - 1)
    return [
        {"key": "brightness", "label": "Brightness", "min": 0, "max": 2000, "step": 1},
        {"key": "exposure", "label": "Exposure", "min": 0, "max": 50000, "step": 100},
        {"key": "analog_gain", "label": "Analog Gain", "min": 0, "max": 24, "step": 1},
        {"key": "digital_gain_x10", "label": "Digital Gain x10", "min": 0, "max": 80, "step": 1},
        {"key": "edge_low", "label": "Edge Low", "min": 0, "max": 255, "step": 1},
        {"key": "edge_high", "label": "Edge High", "min": 0, "max": 255, "step": 1},
        {"key": "main_radius", "label": "Main Radius", "min": 1, "max": 200, "step": 1},
        {"key": "ref_radius", "label": "Ref Radius", "min": 1, "max": 500, "step": 1},
        {"key": "main_cx", "label": "Main Center X", "min": 0, "max": max_x, "step": 1},
        {"key": "main_cy", "label": "Main Center Y", "min": 0, "max": max_y, "step": 1},
        {"key": "ref_cx", "label": "Ref Center X", "min": 0, "max": max_x, "step": 1},
        {"key": "ref_cy", "label": "Ref Center Y", "min": 0, "max": max_y, "step": 1},
    ]

def _clamp_value(value, min_v, max_v):
    return max(int(min_v), min(int(max_v), int(value)))

def _apply_controls_to_circles():
    controls = ui_state["controls"]
    circle_state["radius"] = int(controls["main_radius"])
    circle_state["ref_radius"] = int(controls["ref_radius"])
    circle_state["center"] = (int(controls["main_cx"]), int(controls["main_cy"]))
    circle_state["ref_center"] = (int(controls["ref_cx"]), int(controls["ref_cy"]))

def _sync_controls_from_circles(frame_w, frame_h):
    controls = ui_state["controls"]
    if circle_state.get("center") is None:
        circle_state["center"] = (frame_w // 2, frame_h // 2)
    if circle_state.get("ref_center") is None:
        circle_state["ref_center"] = (min(frame_w - 1, frame_w // 2 + 60), frame_h // 2)
    controls["main_radius"] = int(circle_state.get("radius", controls["main_radius"]))
    controls["ref_radius"] = int(circle_state.get("ref_radius", controls["ref_radius"]))
    controls["main_cx"] = _clamp_value(circle_state["center"][0], 0, max(0, frame_w - 1))
    controls["main_cy"] = _clamp_value(circle_state["center"][1], 0, max(0, frame_h - 1))
    controls["ref_cx"] = _clamp_value(circle_state["ref_center"][0], 0, max(0, frame_w - 1))
    controls["ref_cy"] = _clamp_value(circle_state["ref_center"][1], 0, max(0, frame_h - 1))

def _draw_control_panel(frame_w, frame_h):
    panel_w, panel_h = 560, 760
    panel = np.full((panel_h, panel_w, 3), 28, dtype=np.uint8)
    cv2.putText(panel, "Controls (slider / +/- / set)", (12, 24), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (235, 235, 235), 1)
    cv2.putText(panel, "Mouse: L-click mark/drag | R-click clear circles", (12, 44), cv2.FONT_HERSHEY_SIMPLEX, 0.43, (180, 220, 255), 1)
    cv2.putText(panel, "Buttons/Keys: CROP(c), HOME(h), EDGES(e)", (12, 61), cv2.FONT_HERSHEY_SIMPLEX, 0.43, (180, 220, 255), 1)
    cv2.putText(panel, "Arrows=move | W=target | Space=show/hide", (12, 78), cv2.FONT_HERSHEY_SIMPLEX, 0.43, (180, 220, 255), 1)
    cv2.putText(panel, "S=save | L=load | P=prompt mode | Q=quit", (12, 95), cv2.FONT_HERSHEY_SIMPLEX, 0.43, (180, 220, 255), 1)
    cv2.putText(panel, "M=measure toggle | N=notes toggle", (12, 112), cv2.FONT_HERSHEY_SIMPLEX, 0.43, (180, 220, 255), 1)
    cv2.putText(panel, f"Measure: {ui_state.get('show_measure', 0)}   Notes: {ui_state.get('show_notes', 1)}", (12, 129), cv2.FONT_HERSHEY_SIMPLEX, 0.43, (180, 220, 255), 1)

    controls = ui_state["controls"]
    specs = _control_specs(frame_w, frame_h)
    ui_state["control_widgets"] = {}
    y0 = 160
    row_h = 64

    for idx, spec in enumerate(specs):
        key = spec["key"]
        value = _clamp_value(controls.get(key, spec["min"]), spec["min"], spec["max"])
        controls[key] = value
        y = y0 + idx * row_h
        cv2.putText(panel, spec["label"], (12, y - 8), cv2.FONT_HERSHEY_SIMPLEX, 0.48, (240, 240, 240), 1)

        minus_rect = (12, y + 6, 42, y + 34)
        slider_rect = (56, y + 12, 386, y + 28)
        plus_rect = (398, y + 6, 428, y + 34)
        value_rect = (440, y + 4, 548, y + 36)

        cv2.rectangle(panel, (minus_rect[0], minus_rect[1]), (minus_rect[2], minus_rect[3]), (75, 75, 75), -1)
        cv2.rectangle(panel, (plus_rect[0], plus_rect[1]), (plus_rect[2], plus_rect[3]), (75, 75, 75), -1)
        cv2.putText(panel, "-", (22, y + 27), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
        cv2.putText(panel, "+", (407, y + 27), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

        cv2.rectangle(panel, (slider_rect[0], slider_rect[1]), (slider_rect[2], slider_rect[3]), (60, 60, 60), -1)
        ratio = 0.0 if spec["max"] == spec["min"] else (value - spec["min"]) / (spec["max"] - spec["min"])
        knob_x = int(round(slider_rect[0] + ratio * (slider_rect[2] - slider_rect[0])))
        cv2.circle(panel, (knob_x, (slider_rect[1] + slider_rect[3]) // 2), 8, (0, 180, 255), -1)

        cv2.rectangle(panel, (value_rect[0], value_rect[1]), (value_rect[2], value_rect[3]), (42, 42, 42), -1)
        edit_active = ui_state.get("active_value_edit") == key
        if edit_active:
            cv2.rectangle(panel, (value_rect[0], value_rect[1]), (value_rect[2], value_rect[3]), (0, 180, 255), 1)
            shown_value = f"{ui_state.get('value_edit_buffer', '')}_"
        else:
            shown_value = f"{value}"
        cv2.putText(panel, shown_value, (value_rect[0] + 10, y + 26), cv2.FONT_HERSHEY_SIMPLEX, 0.56, (255, 255, 255), 1)

        ui_state["control_widgets"][key] = {
            "label": spec["label"],
            "min": spec["min"],
            "max": spec["max"],
            "step": spec["step"],
            "minus": minus_rect,
            "plus": plus_rect,
            "slider": slider_rect,
            "value": value_rect,
        }

    return panel

def _set_control_from_slider_x(key, x):
    widget = ui_state["control_widgets"].get(key)
    if widget is None:
        return
    sx1, _, sx2, _ = widget["slider"]
    ratio = 0.0 if sx2 == sx1 else (max(sx1, min(sx2, x)) - sx1) / (sx2 - sx1)
    min_v, max_v = int(widget["min"]), int(widget["max"])
    ui_state["controls"][key] = int(round(min_v + ratio * (max_v - min_v)))

def control_panel_mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        for key, widget in ui_state.get("control_widgets", {}).items():
            if _point_in_rect(x, y, widget["minus"]):
                ui_state["controls"][key] = _clamp_value(ui_state["controls"].get(key, 0) - int(widget["step"]), widget["min"], widget["max"])
                ui_state["controls_dirty"] = True
                ui_state["active_value_edit"] = None
                return
            if _point_in_rect(x, y, widget["plus"]):
                ui_state["controls"][key] = _clamp_value(ui_state["controls"].get(key, 0) + int(widget["step"]), widget["min"], widget["max"])
                ui_state["controls_dirty"] = True
                ui_state["active_value_edit"] = None
                return
            if _point_in_rect(x, y, widget["value"]):
                ui_state["active_value_edit"] = key
                ui_state["value_edit_buffer"] = str(ui_state["controls"].get(key, 0))
                return
            if _point_in_rect(x, y, widget["slider"]):
                ui_state["control_drag"] = key
                _set_control_from_slider_x(key, x)
                ui_state["controls_dirty"] = True
                ui_state["active_value_edit"] = None
                return
    elif event == cv2.EVENT_MOUSEMOVE and ui_state.get("control_drag") is not None:
        _set_control_from_slider_x(ui_state["control_drag"], x)
        ui_state["controls_dirty"] = True
    elif event == cv2.EVENT_LBUTTONUP:
        ui_state["control_drag"] = None

def _handle_value_edit_key(key):
    active_key = ui_state.get("active_value_edit")
    if active_key is None:
        return False
    if key in (13, 10):
        widget = ui_state.get("control_widgets", {}).get(active_key)
        if widget is not None:
            buf = ui_state.get("value_edit_buffer", "").strip()
            if buf:
                try:
                    ui_state["controls"][active_key] = _clamp_value(int(buf), widget["min"], widget["max"])
                    ui_state["controls_dirty"] = True
                except Exception:
                    pass
        ui_state["active_value_edit"] = None
        ui_state["value_edit_buffer"] = ""
        return True
    if key == 27:
        ui_state["active_value_edit"] = None
        ui_state["value_edit_buffer"] = ""
        return True
    if key in (8, 127):
        ui_state["value_edit_buffer"] = ui_state.get("value_edit_buffer", "")[:-1]
        return True
    ch = key & 0xFF
    if 48 <= ch <= 57:
        ui_state["value_edit_buffer"] = ui_state.get("value_edit_buffer", "") + chr(ch)
        return True
    return True

def _safe_ids_bgr(converted_image, fallback_w, fallback_h):
    arr = converted_image.get_numpy_3D()
    if arr is None:
        return None

    w_attr = getattr(converted_image, "Width", None)
    h_attr = getattr(converted_image, "Height", None)
    conv_w = int(w_attr() if callable(w_attr) else (w_attr if w_attr is not None else int(fallback_w)))
    conv_h = int(h_attr() if callable(h_attr) else (h_attr if h_attr is not None else int(fallback_h)))
    target_ratio = conv_w / max(conv_h, 1)

    if arr.ndim == 2:
        arr = cv2.cvtColor(arr, cv2.COLOR_GRAY2BGR)
    elif arr.ndim == 3 and arr.shape[2] == 1:
        arr = cv2.cvtColor(arr[:, :, 0], cv2.COLOR_GRAY2BGR)

    candidates = []
    if arr.ndim == 3 and arr.shape[2] >= 3:
        base = arr[:, :, :3]
        candidates.append(base)
        candidates.append(np.transpose(base, (1, 0, 2)))

    flat = arr.reshape(-1)
    needed = conv_w * conv_h * 3
    if flat.size >= needed:
        reshaped = flat[:needed].reshape((conv_h, conv_w, 3))
        candidates.append(reshaped)
        candidates.append(np.transpose(reshaped, (1, 0, 2)))

    if not candidates:
        return None

    def score(frame):
        h, w = frame.shape[:2]
        ratio = w / max(h, 1)
        return abs(ratio - target_ratio) + (0.01 if min(h, w) < 32 else 0.0)

    best = min(candidates, key=score)
    return np.ascontiguousarray(best.astype(np.uint8, copy=False))

def _letterbox_with_map(frame, target=(1280, 960), src_roi=None):
    tw, th = target
    h, w = frame.shape[:2]
    scale = min(tw / w, th / h)
    nw, nh = int(round(w * scale)), int(round(h * scale))
    resized = cv2.resize(frame, (nw, nh), interpolation=cv2.INTER_LINEAR)
    canvas = np.zeros((th, tw, 3), dtype=np.uint8)
    x0, y0 = (tw - nw) // 2, (th - nh) // 2
    canvas[y0:y0 + nh, x0:x0 + nw] = resized

    if src_roi is None:
        sx, sy, sw, sh = 0, 0, w, h
    else:
        sx, sy, sw, sh = src_roi

    mapping = {
        "x0": x0,
        "y0": y0,
        "nw": nw,
        "nh": nh,
        "src_x": sx,
        "src_y": sy,
        "src_w": sw,
        "src_h": sh,
    }
    return canvas, mapping

def _display_to_base(x, y, mapping):
    if mapping is None:
        return None
    x0, y0, nw, nh = mapping["x0"], mapping["y0"], mapping["nw"], mapping["nh"]
    if nw <= 1 or nh <= 1:
        return None
    if x < x0 or y < y0 or x >= x0 + nw or y >= y0 + nh:
        return None

    rx = (x - x0) / nw
    ry = (y - y0) / nh
    bx = int(round(mapping["src_x"] + rx * (mapping["src_w"] - 1)))
    by = int(round(mapping["src_y"] + ry * (mapping["src_h"] - 1)))
    return bx, by

def _base_to_display(point, mapping):
    if point is None or mapping is None:
        return None
    px, py = point
    sx, sy, sw, sh = mapping["src_x"], mapping["src_y"], mapping["src_w"], mapping["src_h"]
    if px < sx or py < sy or px >= sx + sw or py >= sy + sh:
        return None
    if sw <= 1 or sh <= 1 or mapping["nw"] <= 1 or mapping["nh"] <= 1:
        return None

    rx = (px - sx) / (sw - 1)
    ry = (py - sy) / (sh - 1)
    dx = int(round(mapping["x0"] + rx * (mapping["nw"] - 1)))
    dy = int(round(mapping["y0"] + ry * (mapping["nh"] - 1)))
    return dx, dy

def _base_to_view(point, mapping):
    if point is None or mapping is None:
        return None
    px, py = point
    sx, sy, sw, sh = mapping["src_x"], mapping["src_y"], mapping["src_w"], mapping["src_h"]
    if px < sx or py < sy or px >= sx + sw or py >= sy + sh:
        return None
    return int(px - sx), int(py - sy)

def _radius_to_display(radius, mapping):
    radius = max(1, int(radius))
    if mapping is None:
        return radius
    src_w = max(1, int(mapping["src_w"]))
    src_h = max(1, int(mapping["src_h"]))
    scale_x = float(mapping["nw"]) / src_w
    scale_y = float(mapping["nh"]) / src_h
    return max(1, int(round(radius * min(scale_x, scale_y))))

def _to_edge_frame(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    edge_low = int(ui_state["controls"].get("edge_low", EDGE_CANNY_LOW))
    edge_high = int(ui_state["controls"].get("edge_high", EDGE_CANNY_HIGH))
    edge_low = max(0, min(255, edge_low))
    edge_high = max(edge_low + 1, min(255, edge_high))
    edges = cv2.Canny(blur, edge_low, edge_high)
    return cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

def _draw_buttons(image):
    crop_rect = ui_state["buttons"]["crop"]
    home_rect = ui_state["buttons"]["home"]
    edges_rect = ui_state["buttons"]["edges"]

    crop_color = (0, 170, 255) if circle_state["crop_mode"] else (80, 80, 80)
    home_color = (80, 80, 80)
    edges_color = (0, 170, 255) if ui_state.get("edge_mode", 0) == 1 else (80, 80, 80)

    cv2.rectangle(image, (crop_rect[0], crop_rect[1]), (crop_rect[2], crop_rect[3]), crop_color, -1)
    cv2.rectangle(image, (home_rect[0], home_rect[1]), (home_rect[2], home_rect[3]), home_color, -1)
    cv2.rectangle(image, (edges_rect[0], edges_rect[1]), (edges_rect[2], edges_rect[3]), edges_color, -1)
    cv2.putText(image, "CROP", (crop_rect[0] + 18, crop_rect[1] + 23), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
    cv2.putText(image, "HOME", (home_rect[0] + 15, home_rect[1] + 23), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
    cv2.putText(image, "EDGES", (edges_rect[0] + 10, edges_rect[1] + 23), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

def _handle_circle_mouse(event, bx, by):
    if event == cv2.EVENT_LBUTTONDOWN:
        if circle_state["center"] is None:
            circle_state["center"] = (bx, by)
            add_status_message(f"Main circle at: {circle_state['center']}")
        else:
            dist_main = np.sqrt((bx - circle_state["center"][0]) ** 2 + (by - circle_state["center"][1]) ** 2)
            if dist_main <= circle_state["radius"] + 10:
                circle_state["dragging"] = True
            elif circle_state["ref_center"] is not None:
                dist_ref = np.sqrt((bx - circle_state["ref_center"][0]) ** 2 + (by - circle_state["ref_center"][1]) ** 2)
                if dist_ref <= circle_state["ref_radius"] + 10:
                    circle_state["ref_dragging"] = True
            else:
                circle_state["ref_center"] = (bx, by)
                add_status_message(f"Reference circle at: {circle_state['ref_center']}")

    elif event == cv2.EVENT_MOUSEMOVE:
        if circle_state["dragging"]:
            circle_state["center"] = (bx, by)
        elif circle_state["ref_dragging"]:
            circle_state["ref_center"] = (bx, by)

    elif event == cv2.EVENT_LBUTTONUP:
        if circle_state["dragging"]:
            circle_state["dragging"] = False
            add_status_message(f"Main circle moved to: {circle_state['center']}")
        elif circle_state["ref_dragging"]:
            circle_state["ref_dragging"] = False
            add_status_message(f"Reference circle moved to: {circle_state['ref_center']}")

    elif event == cv2.EVENT_RBUTTONDOWN:
        circle_state["center"] = None
        circle_state["ref_center"] = None
        circle_state["dragging"] = False
        circle_state["ref_dragging"] = False
        add_status_message("Circles cleared")

def mouse_callback(event, x, y, flags, param):
    crop_rect = ui_state["buttons"]["crop"]
    home_rect = ui_state["buttons"]["home"]
    edges_rect = ui_state["buttons"]["edges"]

    if event == cv2.EVENT_LBUTTONDOWN and _point_in_rect(x, y, crop_rect):
        circle_state["crop_mode"] = not circle_state["crop_mode"]
        circle_state["crop_selecting"] = False
        circle_state["crop_start"] = None
        circle_state["crop_current"] = None
        add_status_message("Crop mode ON: drag ROI" if circle_state["crop_mode"] else "Crop mode OFF")
        return

    if event == cv2.EVENT_LBUTTONDOWN and _point_in_rect(x, y, home_rect):
        circle_state["crop_mode"] = False
        circle_state["crop_active"] = False
        circle_state["crop_roi"] = None
        circle_state["crop_selecting"] = False
        circle_state["crop_start"] = None
        circle_state["crop_current"] = None
        add_status_message("Home view restored")
        return

    if event == cv2.EVENT_LBUTTONDOWN and _point_in_rect(x, y, edges_rect):
        ui_state["edge_mode"] = 0 if ui_state.get("edge_mode", 0) == 1 else 1
        add_status_message("Edge mode ON" if ui_state["edge_mode"] == 1 else "Edge mode OFF")
        return

    mapping = ui_state.get("display_map")
    mapped = _display_to_base(x, y, mapping)
    if mapped is None:
        return
    bx, by = mapped

    if circle_state["crop_mode"]:
        if event == cv2.EVENT_LBUTTONDOWN:
            circle_state["crop_selecting"] = True
            circle_state["crop_start"] = (bx, by)
            circle_state["crop_current"] = (bx, by)
        elif event == cv2.EVENT_MOUSEMOVE and circle_state["crop_selecting"]:
            circle_state["crop_current"] = (bx, by)
        elif event == cv2.EVENT_LBUTTONUP and circle_state["crop_selecting"]:
            circle_state["crop_current"] = (bx, by)
            x1, y1 = circle_state["crop_start"]
            x2, y2 = circle_state["crop_current"]
            left, right = sorted((x1, x2))
            top, bottom = sorted((y1, y2))
            if right - left >= 8 and bottom - top >= 8:
                circle_state["crop_roi"] = (left, top, right, bottom)
                circle_state["crop_active"] = True
                add_status_message("Crop applied")
            else:
                add_status_message("Crop ignored (ROI too small)")
            circle_state["crop_mode"] = False
            circle_state["crop_selecting"] = False
            circle_state["crop_start"] = None
            circle_state["crop_current"] = None
        elif event == cv2.EVENT_RBUTTONDOWN:
            circle_state["crop_mode"] = False
            circle_state["crop_selecting"] = False
            circle_state["crop_start"] = None
            circle_state["crop_current"] = None
            add_status_message("Crop cancelled")
        return

    _handle_circle_mouse(event, bx, by)

def save_calibration(filename="calibration_mark.json"):
    if circle_state["center"] or circle_state["ref_center"]:
        data = {
            "center": circle_state["center"],
            "radius": circle_state["radius"],
            "pixel_per_meter": circle_state["pixel_per_meter"],
            "ref_center": circle_state["ref_center"],
            "ref_radius": circle_state["ref_radius"],
        }
        with open(filename, "w") as f:
            json.dump(data, f)
        add_status_message(f"Calibration saved to {filename}")

def load_calibration(filename="calibration_mark.json"):
    if os.path.exists(filename):
        with open(filename, "r") as f:
            data = json.load(f)
        circle_state["center"] = tuple(data["center"]) if data.get("center") else None
        circle_state["radius"] = data.get("radius", 30)
        circle_state["pixel_per_meter"] = data.get("pixel_per_meter")
        circle_state["ref_center"] = tuple(data["ref_center"]) if data.get("ref_center") else None
        circle_state["ref_radius"] = data.get("ref_radius", 100)
        add_status_message(f"Calibration loaded from {filename}")

def _draw_scene(display_img, mapping, show_measure, show_notes):
    if ui_state.get("edge_mode", 0) == 1:
        edge_img = _to_edge_frame(display_img)
        display_img[:, :] = edge_img
        _draw_buttons(display_img)
        return

    ref_display = _base_to_display(circle_state["ref_center"], mapping)
    main_display = _base_to_display(circle_state["center"], mapping)
    ref_view = _base_to_view(circle_state["ref_center"], mapping)
    main_view = _base_to_view(circle_state["center"], mapping)
    ref_display_radius = _radius_to_display(circle_state["ref_radius"], mapping)
    main_display_radius = _radius_to_display(circle_state["radius"], mapping)

    if circle_state.get("show_circles", True) and ref_display is not None and circle_state["ref_radius"] > 0:
        ref_color = (255, 255, 0) if circle_state["ref_dragging"] else (255, 165, 0)
        cv2.circle(display_img, ref_display, ref_display_radius, ref_color, 2)
        cv2.circle(display_img, ref_display, 5, (255, 0, 0), -1)

    if circle_state.get("show_circles", True) and main_display is not None and circle_state["radius"] > 0:
        color = (0, 255, 255) if circle_state["dragging"] else (0, 255, 0)
        cv2.circle(display_img, main_display, main_display_radius, color, 2)
        cv2.circle(display_img, main_display, 3, (0, 0, 255), -1)

        if ref_display is not None and ref_view is not None and main_view is not None:
            dx = main_view[0] - ref_view[0]
            dy = main_view[1] - ref_view[1]
            distance = np.sqrt(dx ** 2 + dy ** 2)
            cv2.line(display_img, main_display, ref_display, (255, 255, 255), 1)
            info_lines = [
                f"Center Offset: {distance:.1f}px (X:{dx:.1f}, Y:{dy:.1f})",
                f"Main Center: ({main_view[0]}, {main_view[1]})",
                f"Ref Center: ({ref_view[0]}, {ref_view[1]})",
                f"Main Diameter: {circle_state['radius'] * 2}px",
                f"Ref Diameter: {circle_state['ref_radius'] * 2}px",
            ]
            panel_top = 50
            line_h = 20
            panel_bottom = panel_top + 10 + len(info_lines) * line_h
            cv2.rectangle(display_img, (10, panel_top), (520, panel_bottom), (0, 0, 0), -1)
            y0 = panel_top + 18
            for i, txt in enumerate(info_lines):
                cv2.putText(display_img, txt, (15, y0 + i * line_h), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 1)

        if show_measure == 1:
            radius_px = circle_state["radius"]
            diameter_px = radius_px * 2
            if circle_state["pixel_per_meter"] is not None:
                radius_m = radius_px / circle_state["pixel_per_meter"]
                diameter_m = diameter_px / circle_state["pixel_per_meter"]
                text1 = f"Radius: {radius_px}px ({radius_m * 1000:.2f}mm)"
                text2 = f"Diameter: {diameter_px}px ({diameter_m * 1000:.2f}mm)"
            else:
                text1 = f"Radius: {radius_px}px"
                text2 = f"Diameter: {diameter_px}px"
            cv2.rectangle(display_img, (10, 165), (520, 225), (0, 0, 0), -1)
            cv2.putText(display_img, text1, (15, 188), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            cv2.putText(display_img, text2, (15, 213), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    if circle_state["crop_mode"] and circle_state["crop_selecting"] and circle_state["crop_start"] and circle_state["crop_current"]:
        p1 = _base_to_display(circle_state["crop_start"], mapping)
        p2 = _base_to_display(circle_state["crop_current"], mapping)
        if p1 is not None and p2 is not None:
            cv2.rectangle(display_img, p1, p2, (255, 255, 255), 2)

    _draw_buttons(display_img)

    if show_notes == 1:
        status_lines = ["=== STATUS ==="]
        line_spacing = 16
        img_h, img_w = display_img.shape[:2]
        panel_h = len(status_lines) * line_spacing + len(status_messages) * line_spacing + 15
        cv2.rectangle(display_img, (img_w - 430, 10), (img_w - 10, panel_h), (0, 0, 0), -1)
        y = 24
        for line in status_lines:
            cv2.putText(display_img, line, (img_w - 420, y), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1)
            y += line_spacing
        for msg in status_messages:
            cv2.putText(display_img, msg[:52], (img_w - 420, y), cv2.FONT_HERSHEY_SIMPLEX, 0.35, (0, 255, 255), 1)
            y += line_spacing

def run_live_camera():
    ids_peak.Library.Initialize()
    device_manager = ids_peak.DeviceManager.Instance()

    device = None
    data_stream = None
    nodemap = None
    key_left = {2424832, 81}
    key_up = {2490368, 82}
    key_right = {2555904, 83}
    key_down = {2621440, 84}

    try:
        device_manager.Update()
        if device_manager.Devices().empty():
            add_status_message("No IDS camera found")
            return

        device = device_manager.Devices()[0].OpenDevice(ids_peak.DeviceAccessType_Control)
        nodemap = device.RemoteDevice().NodeMaps()[0]
        data_stream = device.DataStreams()[0].OpenDataStream()

        payload_size = nodemap.FindNode("PayloadSize").Value()
        for _ in range(data_stream.NumBuffersAnnouncedMinRequired()):
            buffer = data_stream.AllocAndAnnounceBuffer(payload_size)
            data_stream.QueueBuffer(buffer)

        data_stream.StartAcquisition(ids_peak.AcquisitionStartMode_Default)
        nodemap.FindNode("AcquisitionStart").Execute()

        cv2.namedWindow(WINDOW_NAME)
        cv2.setMouseCallback(WINDOW_NAME, mouse_callback)
        cv2.namedWindow(CONTROL_WINDOW_NAME)
        cv2.setMouseCallback(CONTROL_WINDOW_NAME, control_panel_mouse_callback)

        cv2.resizeWindow(CONTROL_WINDOW_NAME, 560, 760)
        cv2.moveWindow(WINDOW_NAME, 0, 0)
        cv2.moveWindow(CONTROL_WINDOW_NAME, 1300, 0)

        add_status_message("IDS camera started")
        add_status_message("Buttons/Keys: CROP(c) | HOME(h) | EDGES(e)")
        add_status_message("Keyboard: S-save | L-load | Q-quit")
        load_calibration()

        while True:
            buffer = data_stream.WaitForFinishedBuffer(5000)
            try:
                raw_image = ids_peak_ipl.Image.CreateFromSizeAndBuffer(
                    buffer.PixelFormat(),
                    buffer.BasePtr(),
                    buffer.Size(),
                    buffer.Width(),
                    buffer.Height(),
                )
                converted_image = raw_image.ConvertTo(ids_peak_ipl.PixelFormatName_BGR8)
                frame = _safe_ids_bgr(converted_image, int(buffer.Width()), int(buffer.Height()))
                if frame is None:
                    continue

                base_h, base_w = frame.shape[:2]
                if circle_state["crop_active"] and circle_state["crop_roi"] is not None:
                    l, t, r, b = circle_state["crop_roi"]
                    l = max(0, min(base_w - 1, l))
                    r = max(0, min(base_w - 1, r))
                    t = max(0, min(base_h - 1, t))
                    b = max(0, min(base_h - 1, b))
                    if r > l and b > t:
                        view = frame[t:b, l:r]
                        src_roi = (l, t, r - l, b - t)
                    else:
                        circle_state["crop_active"] = False
                        circle_state["crop_roi"] = None
                        view = frame
                        src_roi = (0, 0, base_w, base_h)
                else:
                    view = frame
                    src_roi = (0, 0, base_w, base_h)

                display, mapping = _letterbox_with_map(view, (1280, 960), src_roi)
                ui_state["display_map"] = mapping
                if ui_state.get("controls_dirty", False):
                    _apply_controls_to_circles()
                    ui_state["controls_dirty"] = False
                else:
                    _sync_controls_from_circles(base_w, base_h)

                controls = ui_state["controls"]
                brightness = int(controls["brightness"])
                exposure = int(controls["exposure"])
                analog_gain = int(controls["analog_gain"])
                digital_gain_x10 = int(controls["digital_gain_x10"])
                show_measure = int(ui_state.get("show_measure", 0))
                show_notes = int(ui_state.get("show_notes", 1))
                circle_state["pixel_per_meter"] = None

                if brightness != camera_controls["brightness"]:
                    try:
                        nodemap.FindNode("Brightness").SetValue(brightness)
                        camera_controls["brightness"] = brightness
                    except Exception:
                        pass

                if exposure != camera_controls["exposure"]:
                    try:
                        nodemap.FindNode("ExposureTime").SetValue(exposure)
                        camera_controls["exposure"] = exposure
                    except Exception:
                        pass

                if analog_gain != camera_controls["analog_gain"]:
                    try:
                        nodemap.FindNode("Gain").SetValue(analog_gain)
                        camera_controls["analog_gain"] = analog_gain
                    except Exception:
                        pass

                digital_gain_actual = digital_gain_x10 / 10.0
                if digital_gain_x10 != camera_controls["digital_gain"]:
                    try:
                        nodemap.FindNode("DigitalGain").SetValue(digital_gain_actual)
                        camera_controls["digital_gain"] = digital_gain_x10
                    except Exception:
                        pass

                _draw_scene(display, mapping, show_measure, show_notes)
                control_panel = _draw_control_panel(base_w, base_h)
                cv2.imshow(WINDOW_NAME, display)
                cv2.imshow(CONTROL_WINDOW_NAME, control_panel)

                key = cv2.waitKeyEx(1)
                if _handle_value_edit_key(key):
                    continue
                key_low = key & 0xFF
                if key_low == ord("q"):
                    break
                if key_low == ord("s"):
                    save_calibration()
                    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                    shot_stem = _prompt_shot_stem(timestamp) if ui_state.get("prompt_save_name", False) else f"frame_{timestamp}"
                    shot_path = os.path.join(SCREENSHOT_DIR, f"{shot_stem}.png")
                    cv2.imwrite(shot_path, display)
                    add_status_message(f"Screenshot saved to {shot_path}")
                elif key_low == ord("p"):
                    ui_state["prompt_save_name"] = not ui_state.get("prompt_save_name", False)
                    add_status_message("Save prompt mode ON" if ui_state["prompt_save_name"] else "Save prompt mode OFF")
                elif key_low == ord("l"):
                    load_calibration()
                    _sync_controls_from_circles(base_w, base_h)
                elif key_low == ord("c"):
                    circle_state["crop_mode"] = not circle_state["crop_mode"]
                    circle_state["crop_selecting"] = False
                    circle_state["crop_start"] = None
                    circle_state["crop_current"] = None
                    add_status_message("Crop mode ON: drag ROI" if circle_state["crop_mode"] else "Crop mode OFF")
                elif key_low == ord("h"):
                    circle_state["crop_mode"] = False
                    circle_state["crop_active"] = False
                    circle_state["crop_roi"] = None
                    circle_state["crop_selecting"] = False
                    circle_state["crop_start"] = None
                    circle_state["crop_current"] = None
                    add_status_message("Home view restored")
                elif key_low == ord("e"):
                    ui_state["edge_mode"] = 0 if ui_state.get("edge_mode", 0) == 1 else 1
                    add_status_message("Edge mode ON" if ui_state["edge_mode"] == 1 else "Edge mode OFF")
                elif key_low == ord("w"):
                    circle_state["control_target"] = "ref" if circle_state.get("control_target", "main") == "main" else "main"
                    add_status_message("Target: Main circle" if circle_state["control_target"] == "main" else "Target: Reference circle")
                elif key_low == 32:
                    circle_state["show_circles"] = not circle_state.get("show_circles", True)
                    add_status_message("Circles visible" if circle_state["show_circles"] else "Circles hidden")
                elif key_low == ord("m"):
                    ui_state["show_measure"] = 0 if ui_state.get("show_measure", 0) == 1 else 1
                elif key_low == ord("n"):
                    ui_state["show_notes"] = 0 if ui_state.get("show_notes", 1) == 1 else 1
                elif key_low in (ord("="), ord("+")):
                    _adjust_target_radius(1)
                elif key_low == ord("-"):
                    _adjust_target_radius(-1)
                elif key in key_left:
                    _move_selected_circle(-1, 0, base_w, base_h)
                    _sync_controls_from_circles(base_w, base_h)
                elif key in key_right:
                    _move_selected_circle(1, 0, base_w, base_h)
                    _sync_controls_from_circles(base_w, base_h)
                elif key in key_up:
                    _move_selected_circle(0, -1, base_w, base_h)
                    _sync_controls_from_circles(base_w, base_h)
                elif key in key_down:
                    _move_selected_circle(0, 1, base_w, base_h)
                    _sync_controls_from_circles(base_w, base_h)
            finally:
                data_stream.QueueBuffer(buffer)

    except Exception as e:
        add_status_message(f"Error: {e}")

    finally:
        if data_stream is not None and nodemap is not None:
            try:
                nodemap.FindNode("AcquisitionStop").Execute()
                data_stream.StopAcquisition(ids_peak.AcquisitionStopMode_Default)
                data_stream.Flush(ids_peak.DataStreamFlushMode_DiscardAll)
            except Exception:
                pass
        if device is not None:
            del device
        cv2.destroyAllWindows()
        ids_peak.Library.Close()

run_live_camera()

# %% [markdown]
# # IP CAMERA

# %%
import cv2
import numpy as np
import json
import os
from collections import deque
from datetime import datetime

# Set your IP camera stream URL here (path may be /video, /stream, or / depending on camera)
IP_CAMERA_URL = "http://10.0.0.61:8080/video"

# All saved data goes here: calibration JSON + screenshots
SAVE_DIR = r"C:\Users\thaim\Downloads\ip-camera-radius"
IMAGES_DIR = os.path.join(SAVE_DIR, "images")
os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(IMAGES_DIR, exist_ok=True)
CALIBRATION_PATH = os.path.join(SAVE_DIR, "calibration_mark.json")
# --- Shared state and callbacks (so this cell works even if you don't run the IDS camera cell above) ---
if 'mouse_callback' not in dir():
    circle_state = {
        "center": None, "radius": 30, "dragging": False, "pixel_per_meter": None,
        "show_measurements": False, "ref_center": None, "ref_radius": 100, "ref_dragging": False
    }
    camera_controls = {"brightness": 100, "exposure": 5000, "analog_gain": 0, "digital_gain": 10}
    status_messages = deque(maxlen=5)
    def add_status_message(msg):
        status_messages.append(msg)
        print(msg)
    def nothing(*args, **kwargs):
        pass
    def mouse_callback(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            if circle_state["center"] is None:
                circle_state["center"] = (x, y)
                add_status_message(f"Main circle at: {circle_state['center']}")
            else:
                dist_main = np.sqrt((x - circle_state["center"][0])**2 + (y - circle_state["center"][1])**2)
                if dist_main <= circle_state["radius"] + 10:
                    circle_state["dragging"] = True
                elif circle_state["ref_center"] is not None:
                    dist_ref = np.sqrt((x - circle_state["ref_center"][0])**2 + (y - circle_state["ref_center"][1])**2)
                    if dist_ref <= circle_state["ref_radius"] + 10:
                        circle_state["ref_dragging"] = True
                else:
                    circle_state["ref_center"] = (x, y)
                    add_status_message(f"Reference circle at: {circle_state['ref_center']}")
        elif event == cv2.EVENT_MOUSEMOVE:
            if circle_state["dragging"]:
                circle_state["center"] = (x, y)
            elif circle_state["ref_dragging"]:
                circle_state["ref_center"] = (x, y)
        elif event == cv2.EVENT_LBUTTONUP:
            if circle_state["dragging"]:
                circle_state["dragging"] = False
                add_status_message(f"Main circle moved to: {circle_state['center']}")
            elif circle_state["ref_dragging"]:
                circle_state["ref_dragging"] = False
                add_status_message(f"Reference circle moved to: {circle_state['ref_center']}")
        elif event == cv2.EVENT_RBUTTONDOWN:
            circle_state["center"] = circle_state["ref_center"] = None
            circle_state["dragging"] = circle_state["ref_dragging"] = False
            add_status_message("Circles cleared.")
    def save_calibration(filename=None):
        filename = filename or CALIBRATION_PATH
        if circle_state["center"] or circle_state["ref_center"]:
            data = {"center": circle_state["center"], "radius": circle_state["radius"],
                    "pixel_per_meter": circle_state["pixel_per_meter"], "ref_center": circle_state["ref_center"],
                    "ref_radius": circle_state["ref_radius"]}
            with open(filename, 'w') as f:
                json.dump(data, f)
            add_status_message(f"Calibration saved to {filename}")
    def load_calibration(filename=None):
        filename = filename or CALIBRATION_PATH
        if os.path.exists(filename):
            with open(filename, 'r') as f:
                data = json.load(f)
            circle_state["center"] = tuple(data["center"]) if data.get("center") else None
            circle_state["radius"] = data.get("radius", 30)
            circle_state["pixel_per_meter"] = data.get("pixel_per_meter")
            circle_state["ref_center"] = tuple(data["ref_center"]) if data.get("ref_center") else None
            circle_state["ref_radius"] = data.get("ref_radius", 100)
            add_status_message(f"Calibration loaded from {filename}")
    def calculate_pixel_per_meter(sensor_width_mm, image_width_px, focal_length_mm, distance_m):
        sensor_width_m = sensor_width_mm / 1000.0
        object_width_m = (sensor_width_m * distance_m) / focal_length_mm
        return image_width_px / object_width_m

# Use IP camera save path (overrides IDS cell if run after it)
def save_calibration(filename=None):
    filename = filename or CALIBRATION_PATH
    if circle_state["center"] or circle_state["ref_center"]:
        data = {"center": circle_state["center"], "radius": circle_state["radius"], "pixel_per_meter": circle_state["pixel_per_meter"], "ref_center": circle_state["ref_center"], "ref_radius": circle_state["ref_radius"]}
        with open(filename, 'w') as f:
            json.dump(data, f)
        add_status_message(f"Calibration saved to {filename}")
def load_calibration(filename=None):
    filename = filename or CALIBRATION_PATH
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            data = json.load(f)
        circle_state["center"] = tuple(data["center"]) if data.get("center") else None
        circle_state["radius"] = data.get("radius", 30)
        circle_state["pixel_per_meter"] = data.get("pixel_per_meter")
        circle_state["ref_center"] = tuple(data["ref_center"]) if data.get("ref_center") else None
        circle_state["ref_radius"] = data.get("ref_radius", 100)
        add_status_message(f"Calibration loaded from {filename}")

def resize_keep_aspect_ratio(frame, target_size=(1280, 960)):
    """Resize frame to fit inside target_size while preserving aspect ratio (no stretching). Letterboxes with black bars."""
    h, w = frame.shape[:2]
    tw, th = target_size
    scale = min(tw / w, th / h)
    new_w, new_h = int(round(w * scale)), int(round(h * scale))
    resized = cv2.resize(frame, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
    canvas = np.zeros((th, tw, 3), dtype=np.uint8)
    canvas[:] = 0
    x_off = (tw - new_w) // 2
    y_off = (th - new_h) // 2
    canvas[y_off : y_off + new_h, x_off : x_off + new_w] = resized
    return canvas


def run_live_ip_camera(stream_url: str):
    """Run the same calibration GUI using an IP/USB camera via OpenCV VideoCapture.

    Example URLs:
      - RTSP:  "rtsp://user:pass@IP:554/stream"
      - HTTP/MJPEG: "http://IP:8080/video" (depends on camera)
    """
    cap = cv2.VideoCapture(stream_url)
    if not cap.isOpened():
        add_status_message(f"Failed to open camera stream: {stream_url}")
        return

    window_name = "IP Camera - Calibration & Control"
    cv2.namedWindow(window_name)
    cv2.setMouseCallback(window_name, mouse_callback)

    camera_window = "Camera Controls (IP)"
    calib_window = "Calibration Settings (IP)"
    cv2.namedWindow(camera_window)
    cv2.namedWindow(calib_window)

    cv2.resizeWindow(camera_window, 500, 250)
    cv2.resizeWindow(calib_window, 500, 350)

    cv2.moveWindow(window_name, 0, 0)
    cv2.moveWindow(camera_window, 1300, 0)
    cv2.moveWindow(calib_window, 1300, 250)

    # Camera Controls Window (software-applied)
    cv2.createTrackbar("Brightness", camera_window, camera_controls.get("brightness", 100), 2000, nothing)
    cv2.createTrackbar("Exposure", camera_window, camera_controls.get("exposure", 5000), 50000, nothing)
    cv2.createTrackbar("Analog Gain", camera_window, camera_controls.get("analog_gain", 0), 24, nothing)
    cv2.createTrackbar("Digital Gain x10", camera_window, camera_controls.get("digital_gain", 10), 80, nothing)

    # Calibration Settings Window
    cv2.createTrackbar("Radius", calib_window, circle_state.get("radius", 30), 200, nothing)
    cv2.createTrackbar("Ref Radius", calib_window, circle_state.get("ref_radius", 100), 500, nothing)
    cv2.createTrackbar("Measure", calib_window, 0, 1, nothing)
    cv2.createTrackbar("Notes", calib_window, 1, 1, nothing)
    cv2.createTrackbar("Sensor W mm", calib_window, 0, 50, nothing)
    cv2.createTrackbar("Focal mm", calib_window, 0, 200, nothing)
    cv2.createTrackbar("Dist cm", calib_window, 100, 500, nothing)
    cv2.createTrackbar("Width px", calib_window, 1280, 5000, nothing)

    add_status_message("IP camera stream opened.")
    add_status_message("GUI: Camera Controls & Calibration Settings (IP)")
    add_status_message("Left-click: mark/drag circle | Right-click: clear")
    add_status_message("Keyboard: S-save | L-load | Q-quit")

    load_calibration()
    cv2.setTrackbarPos("Radius", calib_window, circle_state["radius"])
    cv2.setTrackbarPos("Ref Radius", calib_window, circle_state["ref_radius"])

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                add_status_message("No frame from IP camera (stream ended?)")
                break

            # Resize preserving aspect ratio (no stretching); letterbox to 1280x960
            img_array = resize_keep_aspect_ratio(frame, (1280, 960))
            img_height, img_width = img_array.shape[:2]

            # Read trackbar values
            brightness = cv2.getTrackbarPos("Brightness", camera_window)
            exposure = cv2.getTrackbarPos("Exposure", camera_window)
            analog_gain = cv2.getTrackbarPos("Analog Gain", camera_window)
            digital_gain_x10 = cv2.getTrackbarPos("Digital Gain x10", camera_window)
            circle_state["radius"] = cv2.getTrackbarPos("Radius", calib_window)
            circle_state["ref_radius"] = cv2.getTrackbarPos("Ref Radius", calib_window)
            show_measure = cv2.getTrackbarPos("Measure", calib_window)
            show_notes = cv2.getTrackbarPos("Notes", calib_window)

            sensor_w = cv2.getTrackbarPos("Sensor W mm", calib_window)
            focal_len = cv2.getTrackbarPos("Focal mm", calib_window)
            distance_cm = cv2.getTrackbarPos("Dist cm", calib_window)
            cam_width_px = cv2.getTrackbarPos("Width px", calib_window)

            if sensor_w > 0 and focal_len > 0 and distance_cm > 0 and cam_width_px > 0:
                distance_m = distance_cm / 100.0
                circle_state["pixel_per_meter"] = calculate_pixel_per_meter(
                    sensor_w, cam_width_px, focal_len, distance_m
                )
            else:
                circle_state["pixel_per_meter"] = None

            # Apply software brightness / gain (simple model)
            alpha = max(0.1, digital_gain_x10 / 10.0)  # contrast (gain)
            beta = brightness - 100                     # brightness offset
            img_array = cv2.convertScaleAbs(img_array, alpha=alpha, beta=beta)

            # --- Drawing overlays: reference circle, main circle, measurements, notes ---
            # (Same as in run_live_camera, but operating on img_array only)
            if circle_state["ref_center"] is not None:
                ref_color = (255, 255, 0) if circle_state["ref_dragging"] else (255, 165, 0)
                cv2.circle(img_array, circle_state["ref_center"], circle_state["ref_radius"], ref_color, 2)
                cv2.circle(img_array, circle_state["ref_center"], 5, (255, 0, 0), -1)
                cv2.line(img_array, (circle_state["ref_center"][0] - circle_state["ref_radius"] - 10, circle_state["ref_center"][1]),
                         (circle_state["ref_center"][0] + circle_state["ref_radius"] + 10, circle_state["ref_center"][1]), ref_color, 1)
                cv2.line(img_array, (circle_state["ref_center"][0], circle_state["ref_center"][1] - circle_state["ref_radius"] - 10),
                         (circle_state["ref_center"][0], circle_state["ref_center"][1] + circle_state["ref_radius"] + 10), ref_color, 1)

            if circle_state["center"] is not None:
                color = (0, 255, 255) if circle_state["dragging"] else (0, 255, 0)
                cv2.circle(img_array, circle_state["center"], circle_state["radius"], color, 2)
                cv2.circle(img_array, circle_state["center"], 3, (0, 0, 255), -1)
                cv2.line(img_array, (circle_state["center"][0] - circle_state["radius"] - 10, circle_state["center"][1]),
                         (circle_state["center"][0] + circle_state["radius"] + 10, circle_state["center"][1]), (0, 255, 0), 1)
                cv2.line(img_array, (circle_state["center"][0], circle_state["center"][1] - circle_state["radius"] - 10),
                         (circle_state["center"][0], circle_state["center"][1] + circle_state["radius"] + 10), (0, 255, 0), 1)

                if circle_state["ref_center"] is not None:
                    dx = circle_state["center"][0] - circle_state["ref_center"][0]
                    dy = circle_state["center"][1] - circle_state["ref_center"][1]
                    distance = np.sqrt(dx**2 + dy**2)
                    cv2.line(img_array, circle_state["center"], circle_state["ref_center"], (255, 255, 255), 1)
                    offset_text = f"Center Offset: {distance:.1f}px (X:{dx:.1f}, Y:{dy:.1f})"
                    cv2.rectangle(img_array, (10, 80), (450, 110), (0, 0, 0), -1)
                    cv2.putText(img_array, offset_text, (15, 100), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)

                if show_measure == 1:
                    radius_px = circle_state["radius"]
                    diameter_px = radius_px * 2
                    if circle_state["pixel_per_meter"] is not None:
                        radius_m = radius_px / circle_state["pixel_per_meter"]
                        diameter_m = diameter_px / circle_state["pixel_per_meter"]
                        text1 = f"Radius: {radius_px}px ({radius_m*1000:.2f}mm)"
                        text2 = f"Diameter: {diameter_px}px ({diameter_m*1000:.2f}mm)"
                    else:
                        text1 = f"Radius: {radius_px}px"
                        text2 = f"Diameter: {diameter_px}px"
                    cv2.rectangle(img_array, (10, 10), (450, 70), (0, 0, 0), -1)
                    cv2.putText(img_array, text1, (15, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                    cv2.putText(img_array, text2, (15, 55), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

            if show_notes == 1:
                instructions = [
                    "=== CONTROLS ===",
                    "Cam: Brightness, Exposure, Gains (software)",
                    "Calib: Circle, Measure, Specs",
                    "Mouse: L-click mark/drag | R-click clear",
                    "Keys: S=save | L=load | Q=quit",
                    "=== STATUS ==="
                ]
                line_spacing = 16
                instr_height = len(instructions) * line_spacing + len(status_messages) * line_spacing + 15
                cv2.rectangle(img_array, (img_width - 420, 10), (img_width - 10, instr_height), (0, 0, 0), -1)
                y_offset = 24
                for instr in instructions:
                    cv2.putText(img_array, instr, (img_width - 410, y_offset),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1)
                    y_offset += line_spacing
                for msg in status_messages:
                    cv2.putText(img_array, msg[:48], (img_width - 410, y_offset),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.35, (0, 255, 255), 1)
                    y_offset += line_spacing

            settings_y = img_height - 120
            cv2.rectangle(img_array, (10, settings_y - 5), (400, img_height - 10), (0, 0, 0), -1)
            cv2.putText(img_array, f"Brightness: {brightness}", (15, settings_y + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.putText(img_array, f"Exposure (SW): {exposure}", (15, settings_y + 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.putText(img_array, f"Analog Gain (SW): {analog_gain}", (15, settings_y + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.putText(img_array, f"Digital Gain: {alpha:.1f}", (15, settings_y + 80), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.putText(img_array, f"Circle Radius: {circle_state['radius']}px", (15, settings_y + 100), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

            cv2.imshow(window_name, img_array)

            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                break
            elif key == ord('s'):
                save_calibration()
                img_path = os.path.join(IMAGES_DIR, f"frame_{datetime.now().strftime('%Y%m%d_%H%M%S')}.png")
                cv2.imwrite(img_path, img_array)
                add_status_message(f"Screenshot saved to {img_path}")
            elif key == ord('l'):
                load_calibration()
                cv2.setTrackbarPos("Radius", calib_window, circle_state["radius"])
                cv2.setTrackbarPos("Ref Radius", calib_window, circle_state["ref_radius"])

    finally:
        cap.release()
        cv2.destroyAllWindows()
        add_status_message("IP camera stream closed.")


run_live_ip_camera(IP_CAMERA_URL)
# Out:
# IP camera stream opened.
# GUI: Camera Controls & Calibration Settings (IP)
# Left-click: mark/drag circle | Right-click: clear
# Keyboard: S-save | L-load | Q-quit
# Calibration loaded from C:\Users\thaim\Downloads\ip-camera-radius\calibration_mark.json
# Main circle moved to: (533, 290)
# Main circle moved to: (529, 289)
# Reference circle moved to: (573, 280)
# Reference circle moved to: (258, 339)
# Main circle moved to: (251, 488)
# IP camera stream closed.
